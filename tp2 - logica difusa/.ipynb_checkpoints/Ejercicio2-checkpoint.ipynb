# %% [markdown]
# # Ejercicio 2 - Ascensor
#
# En un edificio existen tres ascensores que funcionan de manera simultanea. Se quiere crear un sistema que para cada  llamada realizada por cualquier usuario en cualquier piso asigne a cada ascensor un nivel de prioridad dependiendo de el estado en el que se encuentre y seleccione a aquel con mayor prioridad a la respuesta de dicho llamado.
#
# Los elementos a tener en cuenta son:
#
# ### Distancia relativa
#
# Distancia entre la llamada y la ubicación actual del ascensor.
# Se calcula como:
#
# <b>DR</b> = 0 Si el ascensor está en camino al piso llamado
#    IF Está quieto
#       <b>DR</b>= |PISO ACTUAL - PISO DEL LLAMADO|
#    ELSE DR= |PISO DESTINO MAS CERCANO - PISO DEL LLAMADO|
#
# Los conjuntos de pertenencia estarán dados de la siguiente manera:
#
# <table style="font-size:15px;margin-left:0px">
#     <tr>
#         <td>Triangular</td><td>[0 0 2]</td><td>Baja</td>
#     </tr>
#     <tr>
#         <td>Triangular</td><td>[1 3 6]</td><td>Media</td>
#     </tr>
#      <tr>
#         <td>Trapecio</td><td>[5 8 9 9]</td><td>Alta</td>
#     </tr>
# </table>
#
#
# ### Tiempo de espera
#
#
# <b>TE</b> =|PISO ACTUAL - PISO DEL LLAMADO|
#
# <table style="font-size:15px;margin-left:0px">
#     <tr>
#         <td>Trapecio</td><td>[0 0 2 4]</td><td>Corto</td>
#     </tr>
#     <tr>
#         <td>Triangular</td><td>[2 4.5 7]</td><td>Medio</td>
#     </tr>
#      <tr>
#         <td>Trapecio</td><td>[5 7 9 9]</td><td>Largo</td>
#     </tr>
# </table>
#
# <br>
#
# ### Capacidad
#
# <table style="font-size:15px;margin-left:0px">
#     <tr>
#         <td>Trapecio</td><td>[0 0 2 4]</td><td>Baja</td>
#     </tr>
#     <tr>
#         <td>Triangular</td><td>[2 4.5 7]</td><td>Media</td>
#     </tr>
#      <tr>
#         <td>Trapecio</td><td>[5 7 9 9]</td><td>Alta</td>
#     </tr>
# </table>
#
# <br>
#
# ### Prioridad
#
# <table style="font-size:15px;margin-left:0px">
#     <tr>
#         <td>Triangular</td><td>[0 0 0.5]</td><td>Baja</td>
#     </tr>
#     <tr>
#         <td>Triangular</td><td>[0.25 0.5 0.75]</td><td>Media</td>
#     </tr>
#      <tr>
#         <td>Triangular</td><td>[0.5 1 1]</td><td>Alta</td>
#     </tr>
# </table>

# %% [markdown]
#  - Definir un conjunto de reglas para establecer las prioridades a asignar en cada caso
#  - Hacer diversas pruebas y verificar que los resultados sean consistentes

# %%
# %matplotlib inline
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Fuente:</b> https://github.com/shubhamgupta1404/Fuzzy-Elevator-Control-System/blob/master/FuzzyLogicElevatorSystemPaper.pdf

# %% [markdown]
# ## Antecedentes

# %% [markdown]
# ### Distance

# %%
rel_dis = ctrl.Antecedent(np.arange(0,10,1),"rel_dis")
rel_dis["low"] = fuzz.trimf(rel_dis.universe,[0,0,2])
rel_dis["medium"] = fuzz.trimf(rel_dis.universe,[1,3,6])
rel_dis["high"] = fuzz.trapmf(rel_dis.universe,[5,8,9,9])
rel_dis.view()
# Out:
# /home/agustin/anaconda3/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Awaiting time

# %%
aw_time = ctrl.Antecedent(np.arange(0,10,1),"aw_time")
aw_time ["low"] = fuzz.trapmf(aw_time.universe,[0,0,2,4])
aw_time ["medium"] = fuzz.trimf(aw_time.universe,[2,4.5,7])
aw_time ["high"] = fuzz.trapmf(aw_time.universe,[5,7,9,9])
aw_time.view()
# Out:
# /home/agustin/anaconda3/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Capacity

# %%
capacity = ctrl.Antecedent(np.arange(0,10,1),"capacity")
capacity ["low"] = fuzz.trapmf(capacity.universe,[0,0,2,4])
capacity ["medium"] = fuzz.trimf(capacity.universe,[2,4.5,7])
capacity ["high"] = fuzz.trapmf(capacity.universe,[5,7,9,9])
capacity.view()
# Out:
# /home/agustin/anaconda3/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Consecuentes

# %% [markdown]
# ### Priority

# %%
priority = ctrl.Consequent(np.arange(0,1,0.25),"priority")
priority ["low"] = fuzz.trimf(priority.universe,[0,0,0.5])
priority ["medium"] = fuzz.trimf(priority.universe,[0.25,0.5,0.75])
priority ["high"] = fuzz.trimf(priority.universe,[0.5,1,1])
priority.view()
# Out:
# /home/agustin/anaconda3/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Reglas

# %%
priority.deffuzify_method = "mom"
rules = []
rules.append(ctrl.Rule(aw_time["low"] | capacity["low"] | rel_dis["low"], priority["high"]))
rules.append(ctrl.Rule(aw_time["medium"] | rel_dis["medium"] | capacity["medium"], priority["medium"]))
rules.append(ctrl.Rule(aw_time["high"] | rel_dis["high"] | capacity["high"], priority["low"]))

# %% [markdown]
# ## Simulacion

# %% [markdown]
# Persona en planta baja (1). Ascensor A puede estar en piso 3 quieto -> Distanciar = 2, tiempo_espera 2 capacidad 4
#
# Ascensor B piso 2, en movimiento Distanciar = 2 -> tiempo_espera 6 (sube y luego baja) , capacidad = 2
#
# Ascensor C piso 4 , en movimiento a Pbaja DistanciaR = 2 tiempo_esp 2, capacidad = 8
#
#
# Ascensor A piso 1 disr = 3, tiempo_r = 3 capacidad = 8
#
# Ascensor B piso 9 disr = 4, tiempo 4 capacidad = 3
#
# Ascensor C piso 3 disr = 5, tiempo= 5, cap 6

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 1
elevators.input["rel_dis"] = 1
elevators.input["aw_time"] = 1
elevators.compute()
elevators.print_state()
print(f"prioridad: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: aw_time                 = 1
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: capacity                = 1
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: rel_dis                 = 1
#   - low                             : 0.5
#   - medium                          : 0.0
#   - high                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF (aw_time[low] OR capacity[low]) OR rel_dis[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 1.0
#   - capacity[low]                                          : 1.0
#   - rel_dis[low]                                           : 0.5
#            (aw_time[low] OR capacity[low]) OR rel_dis[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
# RULE #1:
#   IF (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.0
#   - rel_dis[medium]                                        : 0.0
#   - capacity[medium]                                       : 0.0
#     (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] = 0.0
#   Activation (THEN-clause):
#                                           priority[medium] : 0.0
#
# RULE #2:
#   IF (aw_time[high] OR rel_dis[high]) OR capacity[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.0
#   - capacity[high]                                         : 0.0
#         (aw_time[high] OR rel_dis[high]) OR capacity[high] = 0.0
#   Activation (THEN-clause):
#                                              priority[low] : 0.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.6666666666666666
#   low:
#     Accumulate using accumulation_max : 0.0
#   medium:
#     Accumulate using accumulation_max : 0.0
#   high:
#     Accumulate using accumulation_max : 1.0
#
# prioridad: 0.6666666666666666

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 4
elevators.input["rel_dis"] = 2
elevators.input["aw_time"] = 2
elevators.compute()
elevators.print_state()
print(f"prioridad: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: aw_time                 = 2
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: capacity                = 4
#   - low                             : 0.0
#   - medium                          : 0.8
#   - high                            : 0.0
# Antecedent: rel_dis                 = 2
#   - low                             : 0.0
#   - medium                          : 0.5
#   - high                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF (aw_time[low] OR capacity[low]) OR rel_dis[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 1.0
#   - capacity[low]                                          : 0.0
#   - rel_dis[low]                                           : 0.0
#            (aw_time[low] OR capacity[low]) OR rel_dis[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
# RULE #1:
#   IF (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.0
#   - rel_dis[medium]                                        : 0.5
#   - capacity[medium]                                       : 0.8
#     (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] = 0.8
#   Activation (THEN-clause):
#                                           priority[medium] : 0.8
#
# RULE #2:
#   IF (aw_time[high] OR rel_dis[high]) OR capacity[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.0
#   - capacity[high]                                         : 0.0
#         (aw_time[high] OR rel_dis[high]) OR capacity[high] = 0.0
#   Activation (THEN-clause):
#                                              priority[low] : 0.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.5316091954022989
#   low:
#     Accumulate using accumulation_max : 0.0
#   medium:
#     Accumulate using accumulation_max : 0.8
#   high:
#     Accumulate using accumulation_max : 1.0
#
# prioridad: 0.5316091954022989

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 2
elevators.input["aw_time"] = 2
elevators.input["rel_dis"] = 6
elevators.compute()
elevators.print_state()
print(f"priority: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: capacity                = 2
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: aw_time                 = 2
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: rel_dis                 = 6
#   - low                             : 0.0
#   - medium                          : 0.0
#   - high                            : 0.3333333333333333
#
# =======
#  Rules
# =======
# RULE #0:
#   IF capacity[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - capacity[low]                                          : 1.0
#                                              capacity[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
# RULE #1:
#   IF (capacity[high] OR aw_time[high]) OR rel_dis[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - capacity[high]                                         : 0.0
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.3333333333333333
#         (capacity[high] OR aw_time[high]) OR rel_dis[high] = 0.3333333333333333
#   Activation (THEN-clause):
#                                              priority[low] : 0.3333333333333333
#
# RULE #2:
#   IF aw_time[medium] OR rel_dis[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.0
#   - rel_dis[medium]                                        : 0.0
#                         aw_time[medium] OR rel_dis[medium] = 0.0
#   Activation (THEN-clause):
#                                           priority[medium] : 0.0
#
# RULE #3:
#   IF aw_time[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 1.0
#                                               aw_time[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
# RULE #4:
#   IF aw_time[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 1.0
#                                               aw_time[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.35249042145593873
#   low:
#     Accumulate using accumulation_max : 0.3333333333333333
#   medium:
#     Accumulate using accumulation_max : 0.0
#   high:
#     Accumulate using accumulation_max : 1.0
#
# priority: 0.35249042145593873

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 8
elevators.input["rel_dis"] = 2
elevators.input["aw_time"] = 2
elevators.compute()
elevators.print_state()
print(f"prioridad: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: aw_time                 = 2
#   - low                             : 1.0
#   - medium                          : 0.0
#   - high                            : 0.0
# Antecedent: capacity                = 8
#   - low                             : 0.0
#   - medium                          : 0.0
#   - high                            : 1.0
# Antecedent: rel_dis                 = 2
#   - low                             : 0.0
#   - medium                          : 0.5
#   - high                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF (aw_time[low] OR capacity[low]) OR rel_dis[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 1.0
#   - capacity[low]                                          : 0.0
#   - rel_dis[low]                                           : 0.0
#            (aw_time[low] OR capacity[low]) OR rel_dis[low] = 1.0
#   Activation (THEN-clause):
#                                             priority[high] : 1.0
#
# RULE #1:
#   IF (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.0
#   - rel_dis[medium]                                        : 0.5
#   - capacity[medium]                                       : 0.0
#     (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] = 0.5
#   Activation (THEN-clause):
#                                           priority[medium] : 0.5
#
# RULE #2:
#   IF (aw_time[high] OR rel_dis[high]) OR capacity[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.0
#   - capacity[high]                                         : 1.0
#         (aw_time[high] OR rel_dis[high]) OR capacity[high] = 1.0
#   Activation (THEN-clause):
#                                              priority[low] : 1.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.3333333333333333
#   low:
#     Accumulate using accumulation_max : 1.0
#   medium:
#     Accumulate using accumulation_max : 0.5
#   high:
#     Accumulate using accumulation_max : 1.0
#
# prioridad: 0.3333333333333333

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 3
elevators.input["aw_time"] = 4
elevators.input["rel_dis"] = 4
elevators.compute()
elevators.print_state()
print(f"priority: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: capacity                = 3
#   - low                             : 0.5
#   - medium                          : 0.4
#   - high                            : 0.0
# Antecedent: aw_time                 = 4
#   - low                             : 0.0
#   - medium                          : 0.8
#   - high                            : 0.0
# Antecedent: rel_dis                 = 4
#   - low                             : 0.0
#   - medium                          : 0.6666666666666666
#   - high                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF capacity[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - capacity[low]                                          : 0.5
#                                              capacity[low] = 0.5
#   Activation (THEN-clause):
#                                             priority[high] : 0.5
#
# RULE #1:
#   IF (capacity[high] OR aw_time[high]) OR rel_dis[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - capacity[high]                                         : 0.0
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.0
#         (capacity[high] OR aw_time[high]) OR rel_dis[high] = 0.0
#   Activation (THEN-clause):
#                                              priority[low] : 0.0
#
# RULE #2:
#   IF aw_time[medium] OR rel_dis[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.8
#   - rel_dis[medium]                                        : 0.6666666666666666
#                         aw_time[medium] OR rel_dis[medium] = 0.8
#   Activation (THEN-clause):
#                                           priority[medium] : 0.8
#
# RULE #3:
#   IF aw_time[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 0.0
#                                               aw_time[low] = 0.0
#   Activation (THEN-clause):
#                                             priority[high] : 0.0
#
# RULE #4:
#   IF aw_time[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 0.0
#                                               aw_time[low] = 0.0
#   Activation (THEN-clause):
#                                             priority[high] : 0.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.5316091954022989
#   low:
#     Accumulate using accumulation_max : 0.0
#   medium:
#     Accumulate using accumulation_max : 0.8
#   high:
#     Accumulate using accumulation_max : 0.5
#
# priority: 0.5316091954022989

# %%
ctrSys = ctrl.ControlSystem(rules)
elevators = ctrl.ControlSystemSimulation(ctrSys)
elevators.input["capacity"] = 8
elevators.input["rel_dis"] = 3
elevators.input["aw_time"] = 3
elevators.compute()
elevators.print_state()
print(f"prioridad: {elevators.output['priority']}")
# Out:
# =============
#  Antecedents
# =============
# Antecedent: aw_time                 = 3
#   - low                             : 0.5
#   - medium                          : 0.4
#   - high                            : 0.0
# Antecedent: capacity                = 8
#   - low                             : 0.0
#   - medium                          : 0.0
#   - high                            : 1.0
# Antecedent: rel_dis                 = 3
#   - low                             : 0.0
#   - medium                          : 1.0
#   - high                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF (aw_time[low] OR capacity[low]) OR rel_dis[low] THEN priority[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[low]                                           : 0.5
#   - capacity[low]                                          : 0.0
#   - rel_dis[low]                                           : 0.0
#            (aw_time[low] OR capacity[low]) OR rel_dis[low] = 0.5
#   Activation (THEN-clause):
#                                             priority[high] : 0.5
#
# RULE #1:
#   IF (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] THEN priority[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[medium]                                        : 0.4
#   - rel_dis[medium]                                        : 1.0
#   - capacity[medium]                                       : 0.0
#     (aw_time[medium] OR rel_dis[medium]) OR capacity[medium] = 1.0
#   Activation (THEN-clause):
#                                           priority[medium] : 1.0
#
# RULE #2:
#   IF (aw_time[high] OR rel_dis[high]) OR capacity[high] THEN priority[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - aw_time[high]                                          : 0.0
#   - rel_dis[high]                                          : 0.0
#   - capacity[high]                                         : 1.0
#         (aw_time[high] OR rel_dis[high]) OR capacity[high] = 1.0
#   Activation (THEN-clause):
#                                              priority[low] : 1.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: priority                 = 0.37037037037037035
#   low:
#     Accumulate using accumulation_max : 1.0
#   medium:
#     Accumulate using accumulation_max : 1.0
#   high:
#     Accumulate using accumulation_max : 0.5
#
# prioridad: 0.37037037037037035
