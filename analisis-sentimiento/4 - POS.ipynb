# %% [markdown]
# # Etiquetado POS
#
# El POS (part of speech) tagging o etiquetado morfológico es el proceso mediante el cual se clasifican las partes de un texto de acuerdo a su clasificación léxica.
#
# Cada palabra recibirá una clasificación léxica a partir de una colección de etiquetas codificadas de acuerdo a su significado en el idioma correspondiente. Para poder realizar un etiquetado POS el texto debe estar previamente tokenizado.
#
# NLKT ofrece una función llamada pos_tag. Esta función clasifica las palabras en ingés según un sistema de codificación pre-definido. Este etiquetador en particular está basado en machine learning y ha sido entrenado a partir de miles de ejemplos de oraciones pre-etiquetadas de manera manual. De esta manera puede estimar la clasificación léxica más probable de un término lo cuál no significa que esté libre de errores.
#
# Es posible obtener una lista completa de los códigos de etiquetado para NLTK

# %%
#nltk.download('tagsets')
#nltk.download('averaged_perceptron_tagger')
import nltk
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# Es posible obtener la descripción cada una categoría específica.

# %%
nltk.help.upenn_tagset("NNP")
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %% [markdown]
# Ya que este etiquetador puede no ser suficiente bueno en algunos casos es posible mejorar la eficiencia del etiquetado sumando etiquetadores POS creados manualmente.

# %% [markdown]
# ## Etiquetado

# %%
example = "The Palace of Westminster serves as the meeting place for both the House of Commons and the House of Lords, the two houses of the Parliament of the United Kingdom. Informally known as the Houses of Parliament after its occupants, the Palace lies on the north bank of the River Thames in the City of Westminster, in central London, England."
# Tokenizar texto
tokenized_text = nltk.word_tokenize(example)
print(tokenized_text)
# Etiquetar texto con pos_tag
text_pos = nltk.pos_tag(tokenized_text)
print(text_pos)
# Out:
# ['The', 'Palace', 'of', 'Westminster', 'serves', 'as', 'the', 'meeting', 'place', 'for', 'both', 'the', 'House', 'of', 'Commons', 'and', 'the', 'House', 'of', 'Lords', ',', 'the', 'two', 'houses', 'of', 'the', 'Parliament', 'of', 'the', 'United', 'Kingdom', '.', 'Informally', 'known', 'as', 'the', 'Houses', 'of', 'Parliament', 'after', 'its', 'occupants', ',', 'the', 'Palace', 'lies', 'on', 'the', 'north', 'bank', 'of', 'the', 'River', 'Thames', 'in', 'the', 'City', 'of', 'Westminster', ',', 'in', 'central', 'London', ',', 'England', '.']
# [('The', 'DT'), ('Palace', 'NNP'), ('of', 'IN'), ('Westminster', 'NNP'), ('serves', 'NNS'), ('as', 'IN'), ('the', 'DT'), ('meeting', 'NN'), ('place', 'NN'), ('for', 'IN'), ('both', 'CC'), ('the', 'DT'), ('House', 'NNP'), ('of', 'IN'), ('Commons', 'NNPS'), ('and', 'CC'), ('the', 'DT'), ('House', 'NNP'), ('of', 'IN'), ('Lords', 'NNPS'), (',', ','), ('the', 'DT'), ('two', 'CD'), ('houses', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Parliament', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('Kingdom', 'NNP'), ('.', '.'), ('Informally', 'RB'), ('known', 'VBN'), ('as', 'IN'), ('the', 'DT'), ('Houses', 'NNP'), ('of', 'IN'), ('Parliament', 'NNP'), ('after', 'IN'), ('its', 'PRP$'), ('occupants', 'NNS'), (',', ','), ('the', 'DT'), ('Palace', 'NNP'), ('lies', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('north', 'JJ'), ('bank', 'NN'), ('of', 'IN'), ('the', 'DT'), ('River', 'NNP'), ('Thames', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('City', 'NNP'), ('of', 'IN'), ('Westminster', 'NNP'), (',', ','), ('in', 'IN'), ('central', 'JJ'), ('London', 'NNP'), (',', ','), ('England', 'NNP'), ('.', '.')]

# %% [markdown]
# # POS en español
#
# Si queremos hacer un etiquetado morfológico en otro idioma entonces es necesario encontrar un etiquetador ya entrenado para ese idioma o entrenar uno nosotros mismos. También es necesario saber cuales son las clasificaciones de palabras existentes para dicho idioma.
#
# En el siguiente <a href="https://colab.research.google.com/github/vitojph/kschool-nlp-18/blob/master/notebooks/pos-tagger-es.ipynb">enlace se muestra un ejemplo práctico de etiquetado POS en español.

# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import string
from nltk.tokenize import TweetTokenizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
url = "https://api.twitter.com/2/tweets/search/recent"
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")

# %% [markdown]
# # Ejercicio
#
# - Obtener de la API una lista de Tweets que no sean retweet y que contengan el hashtag #GRAMMYs en inglés.
# - Realizar la tokenización
# - Realizar un etiquetado POS con la función pos_tag de NLTK
# - Obtener la lista y frecuencia de los sustantivos en singular y plural

# %% [markdown]
# # Ejercicio N°1

# %%
params = {
    'query': '#GRAMMYs  lang:en -is:retweet',
    'tweet.fields':'created_at',
    'max_results':100
}
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"TweeHunch"
}
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-20T19:11:57.000Z', 'id': '1450902629400334340', 'text': '‘Justice’ by Justin Bieber has been submitted for “Album of the Year” while “Peaches” feat. Daniel Caesar and GIVEON vying for “Record of the Year” at the 2022 #Grammys. https://t.co/yL3xZXMuRm'}, {'created_at': '2021-10-20T19:08:11.000Z', 'id': '1450901678727864323', 'text': '#FYC Please consider “The Chopstars” for Best Remixed Recording for the following #ChopNotSlopRemixes #Grammys @ Houston, Texas https://t.co/ORTHOrSdw6'}, {'created_at': '2021-10-20T18:55:14.000Z', 'id': '1450898420135342087', 'text': 'Happy Birthday NBA Youngboy #NBAYoungboy #hiphop #BETAwards #GRAMMYs #Billboards2021 https://t.co/fZWgkXsXua'}, {'created_at': '2021-10-20T18:31:31.000Z', 'id': '1450892451007324161', 'text': "RT @sekouandrews: The reason the #GRAMMYs is music’s highest honor is because it’s music’s only peer-voted award. Today at 3 p.m PT, I'm doing a @TwitterSpaces conversation with the @RecordingAcad to shed light on the power of recognizing music’s creator… https://t.co/BR9vS3Rz6s"}, {'created_at': '2021-10-20T18:30:08.000Z', 'id': '1450892102842388481', 'text': 'Attention @RecordingAcad members: First-round voting opens Friday, Oct 22! Recent "Best Bluegrass Album" recipients include @BillyStrings, @MCFlamekeeper, &amp; @trvlnmccourys!! Who would you like to see take home the gold in 2022?? #GRAMMYs #Vote4GRAMMYs #bluegrass #AmericanRoots https://t.co/0I3zXIFQgy'}, {'created_at': '2021-10-20T18:30:00.000Z', 'id': '1450892070214721538', 'text': 'We have many stories planned &amp; ready for you to read, but what celebrity would you like to see the most in our new magazine? #Hollywood #stars #celebrities #famous #glamour #event #redcarpet #spotlight #fashion #music #Awards #Oscars #GRAMMYs #actress #actor #movie #camera #film'}, {'created_at': '2021-10-20T18:29:33.000Z', 'id': '1450891957979389955', 'text': "#GRAMMYs Voting is critically important because the power, privilege, and prestige of recognizing music’s creators is in the hands of our @RecordingAcademy members. If you're a #RecordingAcademy voting member, don't forget to vote! #Vote4GRAMMYs https://t.co/HINRR9FqJ7"}, {'created_at': '2021-10-20T18:15:25.000Z', 'id': '1450888401507528706', 'text': 'i made a form of 21 AOTY contenders at the #GRAMMYs to see who y’all think is going win, as i have no idea who i think. answer the question on the link, vote as many times as u want &amp; RT, i’m intrigued &lt;3 https://t.co/T4X72fKHPN'}, {'created_at': '2021-10-20T18:14:29.000Z', 'id': '1450888165464674306', 'text': '#FYC Please consider “The Chopstars” for Best Remixed Recording for the following #ChopNotSlopRemixes #Grammys\xa0 #BestRemixedRecording https://t.co/mWmJu5ci2e'}, {'created_at': '2021-10-20T18:09:31.000Z', 'id': '1450886916749111296', 'text': '@buzzbunnyyy Facts #GRAMMYs'}, {'created_at': '2021-10-20T18:04:02.000Z', 'id': '1450885534277062656', 'text': 'Afrika is NOW! ✊🏾 #GRAMMYs #Afrika\n@mpho_sebina @williamlast_krm https://t.co/srfPMAV8AL'}, {'created_at': '2021-10-20T18:03:29.000Z', 'id': '1450885398956228609', 'text': "The reason the #GRAMMYs is music’s highest honor is because it’s music’s only peer-voted award. Today at 3 p.m PT, I'm doing a @TwitterSpaces conversation with the @RecordingAcad to shed light on the power of recognizing music’s creators. #Vote4GRAMMYs \nhttps://t.co/v0NNO7ajHX https://t.co/mtvP22sHmn"}, {'created_at': '2021-10-20T17:52:03.000Z', 'id': '1450882521462415369', 'text': 'Today #British lyricist/ songwriter #LeslieBricusse passed away. Wrote ova 1000 songs 4 film &amp; artists. \n2 #Oscars 9 #Grammys 4 #Tonys \nFrom #JamesBond to “Feeling Good” 4 #NinaSimone \nHe also did score for #WillyWonka movie. \nHere’s my effort to mark his career 👊\n#Steinway 🎹😍 https://t.co/hX15zX2Pms'}, {'created_at': '2021-10-20T17:50:20.000Z', 'id': '1450882089767874568', 'text': '#FYC Please consider “The Chopstars” for Best Remixed Recording for the following #ChopNotSlo ...

# %%
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                   created_at                   id  \
# 0   2021-10-20T19:11:57.000Z  1450902629400334340
# 1   2021-10-20T19:08:11.000Z  1450901678727864323
# 2   2021-10-20T18:55:14.000Z  1450898420135342087
# 3   2021-10-20T18:31:31.000Z  1450892451007324161
# 4   2021-10-20T18:30:08.000Z  1450892102842388481
# ..                       ...                  ...
# 95  2021-10-20T08:21:27.000Z  1450738925656440833
# 96  2021-10-20T08:09:25.000Z  1450735895691214849
# 97  2021-10-20T07:47:35.000Z  1450730399051747328
# 98  2021-10-20T07:46:32.000Z  1450730135297142787
# 99  2021-10-20T07:35:25.000Z  1450727339051130881
#
#                                                  text
# 0   ‘Justice’ by Justin Bieber has been submitted ...
# 1   #FYC Please consider “The Chopstars” for Best ...
# 2   Happy Birthday NBA Youngboy #NBAYoungboy #hiph...
# 3   RT @sekouandrews: The reason the #GRAMMYs is m...
# 4   Attention @RecordingAcad members: First-round ...
# ..                                                ...
# 95          SXY GIRL #GRAMMYs https://t.co/jtIe97UCc8
# 96  #KritiSanon is ecstatic as #ARRahman shares th...
# 97  #GRAMMYs Voting is critically important becaus...
# 98  The #Grammys will stick to its word with the p...
# 99  @724time \nDRE A.M. feat Bruno Mars! @BrunoMar...
#
# [100 rows x 3 columns]

# %%
# Tokenizar

tt = TweetTokenizer()

tokenized_text = df['text'].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df
# Out:
#                   created_at                   id  \
# 0   2021-10-20T19:11:57.000Z  1450902629400334340
# 1   2021-10-20T19:08:11.000Z  1450901678727864323
# 2   2021-10-20T18:55:14.000Z  1450898420135342087
# 3   2021-10-20T18:31:31.000Z  1450892451007324161
# 4   2021-10-20T18:30:08.000Z  1450892102842388481
# ..                       ...                  ...
# 95  2021-10-20T08:21:27.000Z  1450738925656440833
# 96  2021-10-20T08:09:25.000Z  1450735895691214849
# 97  2021-10-20T07:47:35.000Z  1450730399051747328
# 98  2021-10-20T07:46:32.000Z  1450730135297142787
# 99  2021-10-20T07:35:25.000Z  1450727339051130881
#
#                                                  text  \
# 0   ‘Justice’ by Justin Bieber has been submitted ...
# 1   #FYC Please consider “The Chopstars” for Best ...
# 2   Happy Birthday NBA Youngboy #NBAYoungboy #hiph...
# 3   RT @sekouandrews: The reason the #GRAMMYs is m...
# 4   Attention @RecordingAcad members: First-round ...
# ..                                                ...
# 95          SXY GIRL #GRAMMYs https://t.co/jtIe97UCc8
# 96  #KritiSanon is ecstatic as #ARRahman shares th...
# 97  #GRAMMYs Voting is critically important becaus...
# 98  The #Grammys will stick to its word with the p...
# 99  @724time \nDRE A.M. feat Bruno Mars! @BrunoMar...
#
#                                        tokenized_text
# 0   [‘, Justice, ’, by, Justin, Bieber, has, been,...
# 1   [#FYC, Please, consider, “, The, Chopstars, ”,...
# 2   [Happy, Birthday, NBA, Youngboy, #NBAYoungboy,...
# 3   [RT, @sekouandrews, :, The, reason, the, #GRAM...
# 4   [Attention, @RecordingAcad, members, :, First-...
# ..                                                ...
# 95     [SXY, GIRL, #GRAMMYs, https://t.co/jtIe97UCc8]
# 96  [#KritiSanon, is, ecstatic, as, #ARRahman, sha...
# 97  [#GRAMMYs, Voting, is, critically, important, ...
# 98  [The, #Grammys, will, stick, to, its, word, wi...
# 99  [@724time, DRE, A, ., M, ., feat, Bruno, Mars,...
#
# [100 rows x 4 columns]

# %%
# Aplicamos POS

data = []
# Crear lista de palabras
for x in tokenized_text:
    for word in x:
        data.append(word)

# Etiquetar texto con pos_tag
data_pos = nltk.pos_tag(data)
print(data_pos)
data_noun = []
for k,v in data_pos:
    if v in ["NN","NNS"]:
        data_noun.append(k)
print(data_noun)
# Out:
# [('‘', 'JJ'), ('Justice', 'NNP'), ('’', 'NN'), ('by', 'IN'), ('Justin', 'NNP'), ('Bieber', 'NNP'), ('has', 'VBZ'), ('been', 'VBN'), ('submitted', 'VBN'), ('for', 'IN'), ('“', 'NNP'), ('Album', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Year', 'NNP'), ('”', 'NNP'), ('while', 'IN'), ('“', 'JJ'), ('Peaches', 'NNP'), ('”', 'NNP'), ('feat', 'NN'), ('.', '.'), ('Daniel', 'NNP'), ('Caesar', 'NNP'), ('and', 'CC'), ('GIVEON', 'NNP'), ('vying', 'VBG'), ('for', 'IN'), ('“', 'NNP'), ('Record', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Year', 'NNP'), ('”', 'NN'), ('at', 'IN'), ('the', 'DT'), ('2022', 'CD'), ('#Grammys', 'NN'), ('.', '.'), ('https://t.co/yL3xZXMuRm', 'NN'), ('#FYC', 'JJ'), ('Please', 'NNP'), ('consider', 'VB'), ('“', 'NNP'), ('The', 'DT'), ('Chopstars', 'NNP'), ('”', 'NNP'), ('for', 'IN'), ('Best', 'NNP'), ('Remixed', 'NNP'), ('Recording', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('following', 'JJ'), ('#ChopNotSlopRemixes', 'NNS'), ('#Grammys', 'VBP'), ('@', 'JJ'), ('Houston', 'NNP'), (',', ','), ('Texas', 'NNP'), ('https://t.co/ORTHOrSdw6', 'NN'), ('Happy', 'JJ'), ('Birthday', 'NNP'), ('NBA', 'NNP'), ('Youngboy', 'NNP'), ('#NBAYoungboy', 'NNP'), ('#hiphop', 'NNP'), ('#BETAwards', 'NNP'), ('#GRAMMYs', 'NNP'), ('#Billboards2021', 'NNP'), ('https://t.co/fZWgkXsXua', 'NN'), ('RT', 'NNP'), ('@sekouandrews', 'VBZ'), (':', ':'), ('The', 'DT'), ('reason', 'NN'), ('the', 'DT'), ('#GRAMMYs', 'NN'), ('is', 'VBZ'), ('music', 'NN'), ('’', 'NN'), ('s', 'NN'), ('highest', 'JJS'), ('honor', 'NN'), ('is', 'VBZ'), ('because', 'IN'), ('it', 'PRP'), ('’', 'VBZ'), ('s', 'JJ'), ('music', 'NN'), ('’', 'NN'), ('s', 'VBZ'), ('only', 'RB'), ('peer-voted', 'JJ'), ('award', 'NN'), ('.', '.'), ('Today', 'NN'), ('at', 'IN'), ('3', 'CD'), ('p', 'NN'), ('.', '.'), ('m', 'NN'), ('PT', 'NNP'), (',', ','), ("I'm", 'NNP'), ('doing', 'VBG'), ('a', 'DT'), ('@TwitterSpaces', 'NNS'), ('conversation', 'NN'), ('with', 'IN'), ('the', 'DT'), ('@RecordingAcad', 'NN'), ('to', 'TO'), ('shed', 'VB'), ('light', 'NN'), ('on', 'IN'), ('the', 'DT'), ('power', 'NN'), ('of', 'IN'), ('recognizing', 'VBG'), ('music', 'NN'), ('’', 'NNP'), ('s', 'NN'), ('creator', 'NN'), ('…', 'NNP'), ('https://t.co/BR9vS3Rz6s', 'NN'), ('Attention', 'NNP'), ('@RecordingAcad', 'VBZ'), ('members', 'NNS'), (':', ':'), ('First-round', 'JJ'), ('voting', 'NN'), ('opens', 'NNS'), ('Friday', 'NNP'), (',', ','), ('Oct', 'NNP'), ('22', 'CD'), ('!', '.'), ('Recent', 'JJ'), ('"', 'JJ'), ('Best', 'NNP'), ('Bluegrass', 'NNP'), ('Album', 'NNP'), ('"', 'NNP'), ('recipients', 'NNS'), ('include', 'VBP'), ('@BillyStrings', 'NNS'), (',', ','), ('@MCFlamekeeper', 'NNP'), (',', ','), ('&', 'CC'), ('@trvlnmccourys', 'NN'), ('!', '.'), ('!', '.'), ('Who', 'WP'), ('would', 'MD'), ('you', 'PRP'), ('like', 'VB'), ('to', 'TO'), ('see', 'VB'), ('take', 'VB'), ('home', 'NN'), ('the', 'DT'), ('gold', 'NN'), ('in', 'IN'), ('2022', 'CD'), ('?', '.'), ('?', '.'), ('#GRAMMYs', 'JJ'), ('#Vote4GRAMMYs', 'JJ'), ('#bluegrass', 'NN'), ('#AmericanRoots', 'NNS'), ('https://t.co/0I3zXIFQgy', 'VBP'), ('We', 'PRP'), ('have', 'VBP'), ('many', 'JJ'), ('stories', 'NNS'), ('planned', 'VBD'), ('&', 'CC'), ('ready', 'JJ'), ('for', 'IN'), ('you', 'PRP'), ('to', 'TO'), ('read', 'VB'), (',', ','), ('but', 'CC'), ('what', 'WP'), ('celebrity', 'NN'), ('would', 'MD'), ('you', 'PRP'), ('like', 'VB'), ('to', 'TO'), ('see', 'VB'), ('the', 'DT'), ('most', 'JJS'), ('in', 'IN'), ('our', 'PRP$'), ('new', 'JJ'), ('magazine', 'NN'), ('?', '.'), ('#Hollywood', 'JJ'), ('#stars', 'NNS'), ('#celebrities', 'VBZ'), ('#famous', 'JJ'), ('#glamour', 'CD'), ('#event', 'NN'), ('#redcarpet', 'NN'), ('#spotlight', 'NNP'), ('#fashion', 'NN'), ('#music', 'JJ'), ('#Awards', 'NNS'), ('#Oscars', 'NNS'), ('#GRAMMYs', 'VBP'), ('#actress', 'JJ'), ('#actor', 'NN'), ('#movie', 'NNP'), ('#camera', 'NNP'), ('#film', 'NNP'), ('#GRAMMYs', 'NNP'), ('Voting', 'NNP'), ('is', 'VBZ'), ('critically', 'RB'), ('important', 'JJ'), ('because', 'IN'), ('the', 'DT'), ('power', 'NN'), (',', ','), ('privilege', ...
# ['’', 'feat', '”', '#Grammys', 'https://t.co/yL3xZXMuRm', '#ChopNotSlopRemixes', 'https://t.co/ORTHOrSdw6', 'https://t.co/fZWgkXsXua', 'reason', '#GRAMMYs', 'music', '’', 's', 'honor', 'music', '’', 'award', 'Today', 'p', 'm', '@TwitterSpaces', 'conversation', '@RecordingAcad', 'light', 'power', 'music', 's', 'creator', 'https://t.co/BR9vS3Rz6s', 'members', 'voting', 'opens', 'recipients', '@BillyStrings', '@trvlnmccourys', 'home', 'gold', '#bluegrass', '#AmericanRoots', 'stories', 'celebrity', 'magazine', '#stars', '#event', '#redcarpet', '#fashion', '#Awards', '#Oscars', '#actor', 'power', 'privilege', 'prestige', 'music', 's', 'creators', 'hands', 'members', 'voting', 'member', "don't", 'forget', 'https://t.co/HINRR9FqJ7', 'i', 'form', 'contenders', '#GRAMMYs', 'i', 'idea', 'question', 'link', 'vote', 'times', 'i', 'm', 'https://t.co/T4X72fKHPN', '#FYC', '#ChopNotSlopRemixes', 'https://t.co/mWmJu5ci2e', '✊', 'reason', '#GRAMMYs', 'music', '’', 's', 'honor', 'music', '’', 'award', 'Today', 'p', 'm', '@TwitterSpaces', 'conversation', '@RecordingAcad', 'light', 'power', 'music', 's', 'creators', 'https://t.co/mtvP22sHmn', 'lyricist', 'songwriter', 'songs', 'film', 'artists', '#Oscars', '#Tonys', '#JamesBond', '#NinaSimone', 'score', 'movie', 'effort', 'career', 'https://t.co/hX15zX2Pms', '#FYC', '#ChopNotSlopRemixes', '#ChopNotSlopRemixes', 'reasons', '#GRAMMYs', 'honor', 'music', '’', 'award', 'today', 'p', 'm', '@TwitterSpaces', 'conversation', '@RecordingAcad', 'share', 'thoughts', 'power', 'creators', 'https://t.co/iU32mvRbLS', 'members', 'forget', '#yourvoiceyourvote', 'https://t.co/NWvhQVeyVe', '#GRAMMYs', 'music', '’', 's', 'honor', 'community', 's', 'voice', 'Today', 'pm', '@TwitterSpaces', 'conversation', '@RecordingAcad', 'light', 'power', 'prestige', 'privilege', 'music', 's', 'creators', '#ChopNotSlopRemixes', 'https://t.co/4QcILtM7EL', 'evermore', 'Year', '#GRAMMYs', 'music', '’', 's', 'honor', 'music', '’', 'award', 'Today', 'p', 'm', '@TwitterSpaces', 'conversation', 'https://t.co/pUJN68pZDZ', 'pop', 'album', '@SELSREP', 'pop', 'album', '@SELSREP', 'pop', 'album', '#GRAMMYs', 'Vote', 'https://t.co/VIXaWtROE3', 'https://t.co/ffJ4l8ZR2F', 'song', '#GRAMMYs', 'https://t.co/5GiHE6P9uF', 'pop', 'album', '@SELSREP', 'pop', 'album', '#Grammys', 'forget', '”', '#Vote4GRAMMYs', 'voting', 'TODAY', '@GreenViolinist', '@sekouandrews', 'reminder', 'https://t.co/ZO35Fe4HpK', '@Donn_T', 'power', 'privilege', 'prestige', 'music', 's', 'creators', 'hands', 'members', 'voting', 'member', "don't", 'forget', 'https://t.co/4yLOMjTO0q', 'nomination', 'songs', 'voices', '#InPieces', '#DaveGrohl', 'Stage', 'https://t.co/SMwUJOqlIm', '@RollingStone', '#GRAMMYs', 'voting', 'TODAY', '@GreenViolinist', '@sekouandrews', 'reminder', 'https://t.co/1Y927ddGFV', 'https://t.co/xsUjeDy9o7', '@SELSREP', 'pop', 'album', '#Grammys', '#Revelacion', 'pop', 'album', '#ChopNotSlopRemixes', 'https://t.co/H56Hupm0wh', 'power', 'privilege', 'prestige', 'music', 's', 'creators', 'hands', 'members', 'voting', 'member', "don't", 'forget', 'pop', 'album', 'assistam', 'gênio', '#JojoRabbit', 'team', 'win', 'night', '#grammys', 'https://t.co/cCwCYxMLHo', 'voting', 'TODAY', '@GreenViolinist', '@sekouandrews', 'reminder', 'https://t.co/ZO35Fe4HpK', '@Unite4Copyright', '#Inclusion', '👏', 'https://t.co/kSCdQw2rts', '@ColorOfChange', '#GRAMMYs', 'part', 'work', '@RecordingAcad', 'https://t.co/q6I5OLc6nL', '🗓', 'day', '@CarrieUnderwood', 'album', 'song', 'chart', '#Grammys', 'https://t.co/gIislw9mJ3', 'talent', 'record', '#givecredit', 'https://t.co/8sv9S06uY8', 'pop', 'album', '@fanzfandom', 'pop', 'album', 'step', 'look', 'life', 'children', 'music', 'stake', 'inclusion', 'rider', '#BMG', 'pop', 'album', 'https://t.co/TYWsH82php', 'artists', 'collection', 'rarest', 'ones', 'https://t.co/uhjNkDp1UQ', 'artists', 'collection', 'rarest', 'ones', '@SELSREP', 'pop', 'album', '@souveniurs', 'pop', 'album', 'pop', 'album', 'pop', 'album', '@SELSREP', 'pop', 'album', '#Gramm ...

# %%
# Obtener solo: NN - NNS

from nltk.probability import FreqDist

# Obtener frecuencia de cada término
fdist = FreqDist(data_noun)
# Convertir a dataframe
df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
df_fdist.sort_values(by=['Frequency'], inplace=True, ascending=False)
#pd.set_option('display.max_rows', None)

df_fdist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-96861cb1f530> in <module>
#       4
#       5 # Obtener frecuencia de cada término
# ----> 6 fdist = FreqDist(data_noun)
#       7 # Convertir a dataframe
#       8 df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
#
# NameError: name 'data_noun' is not defined

# %% [markdown]
# - Obtener la lista y frecuencia de los nombres propios en singular y plural

# %% [markdown]
# # Ejercicio N°2

# %%
# Aplicamos POS

data = []
# Crear lista de palabras
for x in tokenized_text:
    for word in x:
        data.append(word)

# Etiquetar texto con pos_tag
data_pos = nltk.pos_tag(data)
print(data_pos)
data_names = []
for k,v in data_pos:
    if v in ["NNP","NNPS"]:
        data_names.append(k)
print(data_names)
# Out:
# [('Here', 'RB'), ('we', 'PRP'), ('gow', 'VBP'), ('!', '.'), ('Nothing', 'NN'), ('but', 'CC'), ('SOTY', 'NNP'), ('/', 'NNP'), ('ROTY', 'NNP'), ('behaviour', 'NN'), ('!', '.'), ('@billieeilish', 'JJ'), ('@finneas', 'NNS'), ('#HappierThanEver', 'VBP'), ('#GRAMMYs', 'JJ'), ('🔥', 'NNP'), ('😏', 'NNP'), ('😎', 'NNP'), ('❤', 'NNP'), ('️', 'NNP'), ('💕', 'NNP'), ('🎶', 'NNP'), ('https://t.co/1ze8rRtACr', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'FW'), ('https://t.co/2alXkGP6fY', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'CC'), ('https://t.co/qtLCfTuA5q', 'JJ'), ('YDX', 'NNP'), ('VOL', 'NNP'), ('1', 'CD'), ('otw', 'NN'), ('now', 'RB'), ('https://t.co/TkrY70wiTe', 'VBZ'), ('#tems', 'NNS'), ('#TEMS', 'NNP'), ('#TwitterBan', 'NNP'), ('#drake', 'NNP'), ('#wizkid', 'NNP'), ('#TheRookie', 'NNP'), ('#GRAMMYs', 'NNP'), ('#Burna', 'NNP'), ('Boy', 'NNP'), ('#Ckay', 'NNP'), ('#davido', 'NNP'), ('#SquidGame', 'NNP'), ('#ARMYSelcaDay', 'NNP'), ('#ShahRukhKhan', 'NNP'), ('@DONJAZZY', 'NNP'), ('@MAVINRECORDS', 'NNP'), ('@_VALKlNG', 'NNP'), ('Listen', 'NNP'), ('if', 'IN'), ('u', 'JJ'), ("haven't", 'NN'), ('⬇', 'NNP'), ('️', 'NNP'), ('🎧', 'NNP'), ('💸', 'NNP'), ('#NewMusic', 'NNP'), ('#NowPlaying', 'VBG'), ('#Hits', 'NNS'), ('#Pop', 'NNP'), ('#RAP', 'NNP'), ('#hiphop', 'NNP'), ('#Dance', 'NNP'), ('#Rapper', 'NNP'), ('#TodaysTopHits', 'VBZ'), ('#USA', 'NNP'), ('#radiostation', 'NNP'), ('#music', 'NNP'), ('#Club', 'NNP'), ('#ClubAmerica', 'NNP'), ('#party', 'NNP'), ('#Event', 'NNP'), ('#Dj', 'NNP'), ('#remix', 'NNP'), ('#CoverSong', 'NNP'), ('#covers', 'NNS'), ('#Covid_19', 'VBP'), ('#LGBTQ', 'JJ'), ('#Choreography', 'NNP'), ('#Gym', 'NNP'), ('#recording', 'VBG'), ('#producers', 'NNS'), ('#GRAMMYs', 'VBP'), ('#coachella', 'JJ'), ('#YouTuber', 'NNP'), ('https://t.co/hkEBWf1f0a', 'NN'), ('If', 'IN'), ('the', 'DT'), ('#LGBTQ', 'NN'), ('can', 'MD'), ('be', 'VB'), ('mad', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('#DaBaby', 'NN'), ('then', 'RB'), ('this', 'DT'), ('#fat', 'NN'), ('ugly', 'RB'), ('mark', 'JJ'), ('Henry', 'NNP'), ('looking', 'VBG'), ('ass', 'NN'), ('bitch', 'NN'), ('career', 'NN'), ('should', 'MD'), ('be', 'VB'), ('done', 'VBN'), ('…', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('wrong', 'JJ'), ('😑', 'NN'), ('and', 'CC'), ('you', 'PRP'), ('need', 'VBP'), ('yo', 'JJ'), ('ass', 'NN'), ('whoop', 'NN'), ('Frfr', 'NNP'), ('#BlackTwitter', 'NNP'), ('#chika', 'NNP'), ('#cancelled', 'VBD'), ('#GRAMMYs', 'JJ'), ('#BETHipHopAwards', 'NNS'), ('https://t.co/fYLudufoJL', 'VBP'), ('@_lil6lvckboi', 'JJ'), ('@kanyewest', 'NNP'), ('True', 'NNP'), ('Facts', 'NNP'), ('let', 'VBD'), ('those', 'DT'), ('kanye', 'VB'), ('west', 'JJS'), ('haters', 'NNS'), ('go', 'VBP'), ('and', 'CC'), ('die', 'VBP'), ('#GRAMMYs', 'NNP'), ('#tour', 'NNP'), ('#2021', 'NNP'), ('#trending', 'VBG'), ('#TWICE', 'JJ'), ('#hippop', 'NNP'), ('#pop', 'NNP'), ('Kanye', 'NNP'), ('west', 'JJS'), ('pretty', 'RB'), ('the', 'DT'), ('hotest', 'JJS'), ('in', 'IN'), ('DA', 'NNP'), ('industry', 'NN'), ('and', 'CC'), ('also', 'RB'), ('has', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('album', 'NN'), ('2021', 'CD'), ('...', ':'), ('#hippop', 'NN'), ('#GRAMMYs', 'JJ'), ('#Donda', 'NN'), ('We', 'PRP'), ('wrote', 'VBD'), ('a', 'DT'), ('song', 'NN'), (',', ','), ('"', 'VB'), ('ONE', 'CD'), ('SIDED', 'NNP'), ('LOVE', 'NNP'), ('"', 'NNP'), ('.', '.'), ('Listen', 'VB'), ('to', 'TO'), ('our', 'PR ...
# ['SOTY', '/', 'ROTY', '🔥', '😏', '😎', '❤', '️', '💕', '🎶', '@LionelRichie', 'Album', 'Year', 'GRAMMY', "Can't", 'Slow', 'Down', '@LionelRichie', 'Album', 'Year', 'GRAMMY', "Can't", 'Slow', 'Down', 'YDX', 'VOL', '#TEMS', '#TwitterBan', '#drake', '#wizkid', '#TheRookie', '#GRAMMYs', '#Burna', 'Boy', '#Ckay', '#davido', '#SquidGame', '#ARMYSelcaDay', '#ShahRukhKhan', '@DONJAZZY', '@MAVINRECORDS', '@_VALKlNG', 'Listen', '⬇', '️', '🎧', '💸', '#NewMusic', '#Pop', '#RAP', '#hiphop', '#Dance', '#Rapper', '#USA', '#radiostation', '#music', '#Club', '#ClubAmerica', '#party', '#Event', '#Dj', '#remix', '#CoverSong', '#Choreography', '#Gym', '#YouTuber', 'Henry', 'Frfr', '#BlackTwitter', '#chika', '@kanyewest', 'True', 'Facts', '#GRAMMYs', '#tour', '#2021', '#hippop', '#pop', 'Kanye', 'DA', 'SIDED', 'LOVE', '"', 'MV', 'YouTube', '@billboard', '@RecordingAcad', 'MV', '😉', 'Vote', 'Lagos', 'Grammy', '#GRAMMYs', '#wizkid', 'Song', 'Record', 'THIRD', 'CONSECUTIVE', 'TIME', '😎', '❤', '️', '💕', '🎶', 'Gospel', 'Daily', '@JacquiDHz', '#music', 'Drop', '☹', '️', '#MONTERO', '#GRAMMYs', '/', 'Alison', 'Krauss', 'Recording', 'Academy', '#tunechi', '#Rudielorme', '#lilnasx', '#lilbaby', '#dababy', '#Donda', '#hiphop', '#metroboomin', '#grammys', '#grammy', '#typebeat', '#beat', 'Lemonade', 'Beyoncé', 'Feminist', 'Daily', '#musicnews', 'COMA', '#SoundCloud', '@KIIARA', '#Kehlani', '#MostRequestedLive', '#LilNasX', '#DaBaby', '#6ix9ine', '#The', 'Weeknd', '#playboi', '#Doja', '#Hot100', '#Migos', '#CLB', '#jcole', '#Meek', '#CardiB', '#Roddy', '#GRAMMYs', '#BTSARMY', '#kiiara', '#NewMusic', 'Born', '—', 'NZoe', 'SK', 'Pointblankbx', '@YouTube', '#freestyle', '#Polo', 'G', '#Burna', '#ExpensivePain', '#Eminem', '#Burna', 'Boy', '#DONDA', '#Hot100', '#ColdplayXBTS', '#playboi', '#Lil', 'Wayne', '#Drake', '#BIGBANG', '#Durk', '#Roddy', '#GRAMMYs', 'Kid', '#ACT_BOY', '#BMFSTARZ', "Music's", 'Biggest', 'Night', 'Album', 'Year', '”', '@RecordingAcad', '#Grammys', 'Lemme', 'Bruce', 'Springsteen', '😬', 'Queremos', '#GRAMMYs', 'Munay', '@pedrocapo', 'FUCKIN', 'MASTERPIECE', '💚', '#pedrocapo', "IT'S", 'HAPPENING', 'AGAIN', "LET'S", 'GO', 'LADIES', 'AND', 'GENTLEMEN', "LET'S", 'OVERRIDE', 'THE', 'BLOCKCHAIN', '💨', '#Christinaaguilera', '#grammys', 'Screw', 'Grammys', '#GRAMMYs', '@DoctorFuture_', 'Cannot', 'Right', 'Time', 'Grammy', 'Grammys', 'Weird', '#GRAMMYs', '#OLEWTV', '➡', '️24', '..', 'Ss', '..', '@TheView', '#OLEWMUSIC', '➡', '️24', '#GRAMMYs', '#10X', '#jonstatham', '#singer', '#songwriter', '#musicrow', '#bmi', '#ascap', '#music', '#billboard', '#grammys', '@kelly_rdc', '@RepKinzinger', 'J6', 'Tranny', 'Awards', '⭐', '👑', '#GRAMMYs', '📣', "It's", '#Scotus', 'Greater', 'Good', '#GOP', '#NFL', '#NCAA', '#MLB', '#NBA', '#NHL', '#Oscars', '#Emmys', '#Grammys', '#Tonys', 'GRAMMY', 'Best', 'Album', 'Live', 'Tejano', '#Selena', 'GRAMMY', 'Best', 'Album', 'Live', 'Tejano', '😱', 'Putin', 'Cyprus', 'Monaco', 'Syria', '#NFL', '#NCAA', '#MLB', '#NBA', '#NHL', '#Oscars', '#Emmys', '#Grammys', '#Tonys', '#BestTraditionalPopVocalAlbum', '#BestPopDuoGroupPerformance', '#GRAMMYs', 'LOVE', 'FOR', 'SALE', 'BUYING', 'PARTY', '🕴', '🏽', '🕴', 'IS', 'GONNA', 'BE', 'FIRE', '#lizzo', '#StevieWonder', '#snl', '#SNLPremiere', '#Adele30', '#GRAMMYs', '#Coldplay', '#LadyGaga', '#JBalvin', '#Grimes', '#GwenStefani', '@billboard', '#GrammysSoWhite', 'Wbk', 'March', '#InternationalWomensDay', '😒', '#SCAMMYs', 'Hi', '#OnThisDay', '🇺', '🇸', '#BackstreetBoys', '🌎', '#Grammys', 'Mickey', 'Guyton', 'Black', '—', '#Inktober', 'Day', '#inktober2021day3', '#inktoberday3', '#ladygaga', '#gaga', '#grammys', '#bornthisway', 'Gospel', 'Daily', '@kcur', '@Lynda555E', '#grammys', '#koshergospel', 'Waiting', 'Grammy', 'Best', 'Historical', 'Album', '"', '#jasonburt', 'Story', '#TastyJazzJams', 'Vol', 'December', '#Grammys', '@taylorswift13', '@taylornation13', '#TaylorSwift', '#TaylorsVersion', 'JIMIN', '#Post1', '#BTSJIMIN', '#ParkJimin', '#GRAMMYs', '#grammy', '#JIMINDAY', '#HappyJiminDay', '#jimtobe ...

# %%
# Obtener solo: NN - NNS

from nltk.probability import FreqDist

# Obtener frecuencia de cada término
fdist = FreqDist(data_names)
# Convertir a dataframe
df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
df_fdist.sort_values(by=['Frequency'], inplace=True, ascending=False)
#pd.set_option('display.max_rows', None)

df_fdist
# Out:
#                Frequency
# Term
# #GRAMMYs              37
# Album                 13
# Year                   9
# Best                   9
# God                    8
# ...                  ...
# Tranny                 1
# J6                     1
# @RepKinzinger          1
# @kelly_rdc             1
# 🗽                      1
#
# [531 rows x 1 columns]

# %% [markdown]
# - Obtener la lista y frecuencia de los verbos en todos los tiempos verbales

# %% [markdown]
# # Ejercicio N°3

# %%
# Aplicamos POS

data = []
# Crear lista de palabras
for x in tokenized_text:
    for word in x:
        data.append(word)

# Etiquetar texto con pos_tag
data_pos = nltk.pos_tag(data)
print(data_pos)
data_verbs = []
for k,v in data_pos:
    if v in ["VBZ", "VBP", "VBN", "VBG", "VBD", "VB"]:
        data_verbs.append(k)
print(data_verbs)
# Out:
# [('Here', 'RB'), ('we', 'PRP'), ('gow', 'VBP'), ('!', '.'), ('Nothing', 'NN'), ('but', 'CC'), ('SOTY', 'NNP'), ('/', 'NNP'), ('ROTY', 'NNP'), ('behaviour', 'NN'), ('!', '.'), ('@billieeilish', 'JJ'), ('@finneas', 'NNS'), ('#HappierThanEver', 'VBP'), ('#GRAMMYs', 'JJ'), ('🔥', 'NNP'), ('😏', 'NNP'), ('😎', 'NNP'), ('❤', 'NNP'), ('️', 'NNP'), ('💕', 'NNP'), ('🎶', 'NNP'), ('https://t.co/1ze8rRtACr', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'FW'), ('https://t.co/2alXkGP6fY', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'CC'), ('https://t.co/qtLCfTuA5q', 'JJ'), ('YDX', 'NNP'), ('VOL', 'NNP'), ('1', 'CD'), ('otw', 'NN'), ('now', 'RB'), ('https://t.co/TkrY70wiTe', 'VBZ'), ('#tems', 'NNS'), ('#TEMS', 'NNP'), ('#TwitterBan', 'NNP'), ('#drake', 'NNP'), ('#wizkid', 'NNP'), ('#TheRookie', 'NNP'), ('#GRAMMYs', 'NNP'), ('#Burna', 'NNP'), ('Boy', 'NNP'), ('#Ckay', 'NNP'), ('#davido', 'NNP'), ('#SquidGame', 'NNP'), ('#ARMYSelcaDay', 'NNP'), ('#ShahRukhKhan', 'NNP'), ('@DONJAZZY', 'NNP'), ('@MAVINRECORDS', 'NNP'), ('@_VALKlNG', 'NNP'), ('Listen', 'NNP'), ('if', 'IN'), ('u', 'JJ'), ("haven't", 'NN'), ('⬇', 'NNP'), ('️', 'NNP'), ('🎧', 'NNP'), ('💸', 'NNP'), ('#NewMusic', 'NNP'), ('#NowPlaying', 'VBG'), ('#Hits', 'NNS'), ('#Pop', 'NNP'), ('#RAP', 'NNP'), ('#hiphop', 'NNP'), ('#Dance', 'NNP'), ('#Rapper', 'NNP'), ('#TodaysTopHits', 'VBZ'), ('#USA', 'NNP'), ('#radiostation', 'NNP'), ('#music', 'NNP'), ('#Club', 'NNP'), ('#ClubAmerica', 'NNP'), ('#party', 'NNP'), ('#Event', 'NNP'), ('#Dj', 'NNP'), ('#remix', 'NNP'), ('#CoverSong', 'NNP'), ('#covers', 'NNS'), ('#Covid_19', 'VBP'), ('#LGBTQ', 'JJ'), ('#Choreography', 'NNP'), ('#Gym', 'NNP'), ('#recording', 'VBG'), ('#producers', 'NNS'), ('#GRAMMYs', 'VBP'), ('#coachella', 'JJ'), ('#YouTuber', 'NNP'), ('https://t.co/hkEBWf1f0a', 'NN'), ('If', 'IN'), ('the', 'DT'), ('#LGBTQ', 'NN'), ('can', 'MD'), ('be', 'VB'), ('mad', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('#DaBaby', 'NN'), ('then', 'RB'), ('this', 'DT'), ('#fat', 'NN'), ('ugly', 'RB'), ('mark', 'JJ'), ('Henry', 'NNP'), ('looking', 'VBG'), ('ass', 'NN'), ('bitch', 'NN'), ('career', 'NN'), ('should', 'MD'), ('be', 'VB'), ('done', 'VBN'), ('…', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('wrong', 'JJ'), ('😑', 'NN'), ('and', 'CC'), ('you', 'PRP'), ('need', 'VBP'), ('yo', 'JJ'), ('ass', 'NN'), ('whoop', 'NN'), ('Frfr', 'NNP'), ('#BlackTwitter', 'NNP'), ('#chika', 'NNP'), ('#cancelled', 'VBD'), ('#GRAMMYs', 'JJ'), ('#BETHipHopAwards', 'NNS'), ('https://t.co/fYLudufoJL', 'VBP'), ('@_lil6lvckboi', 'JJ'), ('@kanyewest', 'NNP'), ('True', 'NNP'), ('Facts', 'NNP'), ('let', 'VBD'), ('those', 'DT'), ('kanye', 'VB'), ('west', 'JJS'), ('haters', 'NNS'), ('go', 'VBP'), ('and', 'CC'), ('die', 'VBP'), ('#GRAMMYs', 'NNP'), ('#tour', 'NNP'), ('#2021', 'NNP'), ('#trending', 'VBG'), ('#TWICE', 'JJ'), ('#hippop', 'NNP'), ('#pop', 'NNP'), ('Kanye', 'NNP'), ('west', 'JJS'), ('pretty', 'RB'), ('the', 'DT'), ('hotest', 'JJS'), ('in', 'IN'), ('DA', 'NNP'), ('industry', 'NN'), ('and', 'CC'), ('also', 'RB'), ('has', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('album', 'NN'), ('2021', 'CD'), ('...', ':'), ('#hippop', 'NN'), ('#GRAMMYs', 'JJ'), ('#Donda', 'NN'), ('We', 'PRP'), ('wrote', 'VBD'), ('a', 'DT'), ('song', 'NN'), (',', ','), ('"', 'VB'), ('ONE', 'CD'), ('SIDED', 'NNP'), ('LOVE', 'NNP'), ('"', 'NNP'), ('.', '.'), ('Listen', 'VB'), ('to', 'TO'), ('our', 'PR ...
# ['gow', '#HappierThanEver', 'won', 'won', 'https://t.co/TkrY70wiTe', '#NowPlaying', '#TodaysTopHits', '#Covid_19', '#recording', '#GRAMMYs', 'be', 'looking', 'be', 'done', 'is', 'need', '#cancelled', 'https://t.co/fYLudufoJL', 'let', 'kanye', 'go', 'die', '#trending', 'has', 'wrote', '"', 'Listen', 'watch', '⬇', '#songwriter', 'is', 'wizkid', 'made', '#MusicOfTheSpheres', 'is', 'is', 'made', 'hate', "don't", 'talk', '#HappierThanEver', 'https://t.co/pY6CQ6ve9m', '@kcur', '#grammys', 'waiting', 'say', 'performing', 'was', 'tied', 'remains', 'accomplish', 'according', 'is', 'be', 'Making', 'https://t.co/HZ6kAvdDzf', '#Poke', '#Rich', 'coming', 'Excited', 'smiles', '*', '’', 'been', 'listening', 'say', '…', 'are', 'going', 'be', 'goes', 'is', 'is', 'is', 'enough', 'EGOT', 'be', '#GRAMMYs', '’', 'aren', 'including', 'are', 'managing', 'be', '🧐', '/', '/', 'Want', 'call', '#artist', 'was', 'Look', 'are', 'vilified', 'shamed', 'is', '#Dems', 'comes', 'won', 'marking', 'won', 'won', 'marking', 'won', 'is', 'hidden', '#Dems', 'Trending', 'were', 'postponed', 'coincided', 'avoid', 'win', 'turns', 'released', 'nominated', 'awarded', 'includes', '#90s', 'https://t.co/psgAlCfl1r', 'comes', 'made', 'perform', 'calls', 'truly', 'am', 'being', 'freeing', '”', 'was', '”', 'https://t.co/y5SBHEwzu6', '@77BlueJays', '@SouthernGemGal', '#nickyhopkins', '@Alish3211_', 'see', 'is', 'produced', 'was', 'appear', 'coming', 'was', 'snubbed', 'laughing', 'go', 'till', '💜', 'According', 'i', 'love', '"', 'is', 'dropping', '#TiktokTrends', '#recording', '#TodaysTopHits', '#iTunes', '#Trending', 'have', 'want', 'gift', '@fame_ladies', 'get', 'holler', 'https://t.co/jeQvuGrlGN', '@Lynda555E', 'deserves', 'https://t.co/wSDO8oOdSY', 'like', "there's", 'is', 'recorded', 'signed', 'was', 'won', 'is', 'Making', 'https://t.co/PnQLeq95l4', '✨', '#drawing', '#painting', 's', 'wedding', 'is', 'believe', '’', '#1989iscoming', '@djkhaled', 'is', 'be', 'nominated', 'be', 'receive', 'know', 'is', 'have', 'been', 'hearing', 'is', 'come', '/', 'do', 'is', '#GRAMMYs', '#MyUniverse', 'is', 'performed', 'looking', 'are', 'are', 'watching', 'are', 'posting', 'had', 'tweet', 'mentioning', 'sites', 'added', 's', 'following', 'score', 'https://t.co/RtbvPSVelD', 'score', 'https://t.co/vMngfyqN3N', 'does', 'have', 'know', 'has', 'wrote', 'forwarded', 'was', 'cancelled', 'added', 'wrote', 'sang', "I'm", 'did', '"', '+', 'has', 'been', 'named', 'be', 'https://t.co/2cesBDCBQG', 'does', 'have', '#tiktoktrends', '#Celebrities', 'https://t.co/DMTnqHriI0', 'be', 'nominated', 'Certified', '#ArianaGrande', 'has', 'received', 'winning', 'are', 'was', 'inducted', 'has', 'collaborated', '@JLangWood', 'afford', 'getting', 'make', 'attending', 'Looking', 'televised', '#AttendeesAndNominees', 'loved', 'bts', 'continue', 'sell', 'have', 'learned', 'respect', '#GRAMMYs', 's', 'take', '+', 'has', 'been', 'named', 'be', 'https://t.co/60HUPdcjm3', '@Lynda555E', '~', 'is', 'Wanted', 'is', 'is', 'refreshing', 'inundated', 'is', 'is', 'refreshing', 'inundated', 'acknowledging', 'being', 'know', 'suffer', 'lose', 'forget', 'quit', 'was', 'be', '#GRAMMYs', 'see', 'say', 'is', 'win', 'laugh', 'forget', 'Have', 'forgotten', 'have', 'tagged', "can't", 'find', '#GRAMMYs', 'Expose', 'Expose', 'awaiting', 'turn', 'be', 'be', 'lifted', '#GRAMMYs', 'Expose', 'Expose', 'awaiting', 'turn', 'be', 'be', 'lifted', '#GRAMMYs', 'Expose', 'Expose', 'awaiting', 'turn', 'be', 'be', 'lifted', '#GRAMMYs', '#grammys', 'Expose', 'Expose', 'awaiting', 'turn', 'be', 'be', 'lifted', '#mixing', '#mixingandmastering', '#recording', '#musicproducer', '#musicproduction']

# %%
from nltk.probability import FreqDist

# Obtener frecuencia de cada término
fdist = FreqDist(data_verbs)
# Convertir a dataframe
df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
df_fdist.sort_values(by=['Frequency'], inplace=True, ascending=False)
#pd.set_option('display.max_rows', None)

df_fdist
# Out:
#                          Frequency
# Term
# is                              26
# be                              20
# was                              9
# #GRAMMYs                         9
# Expose                           8
# ...                            ...
# https://t.co/psgAlCfl1r          1
# perform                          1
# calls                            1
# truly                            1
# #musicproduction                 1
#
# [214 rows x 1 columns]

# %% [markdown]
# - Obtener la lista y frecuencia de todos los adjetivos

# %% [markdown]
# # Ejercicio N°3

# %%
# Aplicamos POS

data = []
# Crear lista de palabras
for x in tokenized_text:
    for word in x:
        data.append(word)

# Etiquetar texto con pos_tag
data_pos = nltk.pos_tag(data)
print(data_pos)
data_adjective = []
for k,v in data_pos:
    if v in ["JJ", "JJR", "JJS"]: # "JJ", "JJR", "JJS"
        data_adjective.append(k)
print(data_adjective)
# Out:
# [('Here', 'RB'), ('we', 'PRP'), ('gow', 'VBP'), ('!', '.'), ('Nothing', 'NN'), ('but', 'CC'), ('SOTY', 'NNP'), ('/', 'NNP'), ('ROTY', 'NNP'), ('behaviour', 'NN'), ('!', '.'), ('@billieeilish', 'JJ'), ('@finneas', 'NNS'), ('#HappierThanEver', 'VBP'), ('#GRAMMYs', 'JJ'), ('🔥', 'NNP'), ('😏', 'NNP'), ('😎', 'NNP'), ('❤', 'NNP'), ('️', 'NNP'), ('💕', 'NNP'), ('🎶', 'NNP'), ('https://t.co/1ze8rRtACr', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'FW'), ('https://t.co/2alXkGP6fY', 'NN'), ('At', 'IN'), ('the', 'DT'), ('27th', 'CD'), ('#GRAMMYs', 'NN'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('@LionelRichie', 'NNP'), ('won', 'VBD'), ('the', 'DT'), ('Album', 'NNP'), ('Of', 'IN'), ('The', 'DT'), ('Year', 'NNP'), ('GRAMMY', 'NNP'), ('for', 'IN'), ("'", "''"), ("Can't", 'NNP'), ('Slow', 'NNP'), ('Down', 'NNP'), ("'", 'POS'), ('.', '.'), ('🎶', 'CC'), ('https://t.co/qtLCfTuA5q', 'JJ'), ('YDX', 'NNP'), ('VOL', 'NNP'), ('1', 'CD'), ('otw', 'NN'), ('now', 'RB'), ('https://t.co/TkrY70wiTe', 'VBZ'), ('#tems', 'NNS'), ('#TEMS', 'NNP'), ('#TwitterBan', 'NNP'), ('#drake', 'NNP'), ('#wizkid', 'NNP'), ('#TheRookie', 'NNP'), ('#GRAMMYs', 'NNP'), ('#Burna', 'NNP'), ('Boy', 'NNP'), ('#Ckay', 'NNP'), ('#davido', 'NNP'), ('#SquidGame', 'NNP'), ('#ARMYSelcaDay', 'NNP'), ('#ShahRukhKhan', 'NNP'), ('@DONJAZZY', 'NNP'), ('@MAVINRECORDS', 'NNP'), ('@_VALKlNG', 'NNP'), ('Listen', 'NNP'), ('if', 'IN'), ('u', 'JJ'), ("haven't", 'NN'), ('⬇', 'NNP'), ('️', 'NNP'), ('🎧', 'NNP'), ('💸', 'NNP'), ('#NewMusic', 'NNP'), ('#NowPlaying', 'VBG'), ('#Hits', 'NNS'), ('#Pop', 'NNP'), ('#RAP', 'NNP'), ('#hiphop', 'NNP'), ('#Dance', 'NNP'), ('#Rapper', 'NNP'), ('#TodaysTopHits', 'VBZ'), ('#USA', 'NNP'), ('#radiostation', 'NNP'), ('#music', 'NNP'), ('#Club', 'NNP'), ('#ClubAmerica', 'NNP'), ('#party', 'NNP'), ('#Event', 'NNP'), ('#Dj', 'NNP'), ('#remix', 'NNP'), ('#CoverSong', 'NNP'), ('#covers', 'NNS'), ('#Covid_19', 'VBP'), ('#LGBTQ', 'JJ'), ('#Choreography', 'NNP'), ('#Gym', 'NNP'), ('#recording', 'VBG'), ('#producers', 'NNS'), ('#GRAMMYs', 'VBP'), ('#coachella', 'JJ'), ('#YouTuber', 'NNP'), ('https://t.co/hkEBWf1f0a', 'NN'), ('If', 'IN'), ('the', 'DT'), ('#LGBTQ', 'NN'), ('can', 'MD'), ('be', 'VB'), ('mad', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('#DaBaby', 'NN'), ('then', 'RB'), ('this', 'DT'), ('#fat', 'NN'), ('ugly', 'RB'), ('mark', 'JJ'), ('Henry', 'NNP'), ('looking', 'VBG'), ('ass', 'NN'), ('bitch', 'NN'), ('career', 'NN'), ('should', 'MD'), ('be', 'VB'), ('done', 'VBN'), ('…', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('wrong', 'JJ'), ('😑', 'NN'), ('and', 'CC'), ('you', 'PRP'), ('need', 'VBP'), ('yo', 'JJ'), ('ass', 'NN'), ('whoop', 'NN'), ('Frfr', 'NNP'), ('#BlackTwitter', 'NNP'), ('#chika', 'NNP'), ('#cancelled', 'VBD'), ('#GRAMMYs', 'JJ'), ('#BETHipHopAwards', 'NNS'), ('https://t.co/fYLudufoJL', 'VBP'), ('@_lil6lvckboi', 'JJ'), ('@kanyewest', 'NNP'), ('True', 'NNP'), ('Facts', 'NNP'), ('let', 'VBD'), ('those', 'DT'), ('kanye', 'VB'), ('west', 'JJS'), ('haters', 'NNS'), ('go', 'VBP'), ('and', 'CC'), ('die', 'VBP'), ('#GRAMMYs', 'NNP'), ('#tour', 'NNP'), ('#2021', 'NNP'), ('#trending', 'VBG'), ('#TWICE', 'JJ'), ('#hippop', 'NNP'), ('#pop', 'NNP'), ('Kanye', 'NNP'), ('west', 'JJS'), ('pretty', 'RB'), ('the', 'DT'), ('hotest', 'JJS'), ('in', 'IN'), ('DA', 'NNP'), ('industry', 'NN'), ('and', 'CC'), ('also', 'RB'), ('has', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('album', 'NN'), ('2021', 'CD'), ('...', ':'), ('#hippop', 'NN'), ('#GRAMMYs', 'JJ'), ('#Donda', 'NN'), ('We', 'PRP'), ('wrote', 'VBD'), ('a', 'DT'), ('song', 'NN'), (',', ','), ('"', 'VB'), ('ONE', 'CD'), ('SIDED', 'NNP'), ('LOVE', 'NNP'), ('"', 'NNP'), ('.', '.'), ('Listen', 'VB'), ('to', 'TO'), ('our', 'PR ...
# ['@billieeilish', '#GRAMMYs', 'https://t.co/qtLCfTuA5q', 'u', '#LGBTQ', '#coachella', 'mad', 'mark', 'wrong', 'yo', '#GRAMMYs', '@_lil6lvckboi', 'west', '#TWICE', 'west', 'hotest', 'best', '#GRAMMYs', 'official', '️', '#music', '#Song', 'official', 'https://t.co/vxlqlh0xrV', '"', '"', '@billieeilish', '👏', '🙌', 'latest', 'more', 'awarded', 'only', 'tom', '#GRAMMYs', '#kanyewest', '#southside', 'latest', '#grammys', '#BillieEilish', '#CLB', 'top', 'most', 'likely', '“', 'next', 'disappointed', 'MORE', '#LEPATHLON', 'favorite', 'awesomest', '#GoldenGlobes', '#Emmys', 's', 'many', '’', '‘', 'oblivious', 'greatest', '\U0001f972', '(310) 882-1967', 'Recent', 'worthy', 'partisan', '🇺', '🇸', 'annual', "it's", 'likely', '#Selena', 'first', 'Mexican-American', 'first', 'female', '✨', '#HispanicHeritageMonth', 'first', 'Mexican-American', 'first', 'female', '✨', '#HispanicHeritageMonth', 'richest', '#BlackLivesMatter', '@RecordingAcad', 'white', 'like', 'singer', '️at', '#HappyBirthday', 'min', 'annual', "it's", 'likely', 'first', 'long', 'most', 'authentic', 'https://t.co/cVclFZQmjA', 'https://t.co/LrNftGoJnW', '#inktober2021', 'latest', 'Grateful', 'Daily', 'latest', '"', 'upcoming', 'angry', 'happy', '#JIMINDay_D10', '#day21', '#tiktok', 'https://t.co/SFJSoOCjkP', 'nft', 'latest', '#music', 'Stevie', 'musical', '#gunna', 'favorite', '#TaylorSwift', 'last', 'such', 's', '😭', 'possible', 'credited', 'eligible', 'victorious', 'possible', 'enough', 'right', 'great', '#music', 'https://t.co/ZI5nhU5qhC', 'global', '🌎', 'unparalleled', '#BUTTER', '😏', 'real', 'single', '#GRAMMYs', 'other', 'voted', 'last', '#GRAMMYs', 'late', 'early', '…', 'wildcard', '#GRAMMYs', 'wildcard', 'many', '⭐', '#trivia', '🏆', 'own', '"', 'melodic', 'big', '#SUGA', '@BillieEilish', 's', 'self-directed', 'special', 'likely', 'many', '⭐', '#RAP', 'likely', 'Happier', '#BillieEilish', 'loaner', 'goodie', 'more', 'most', 'other', 'most', 'song', '#BTSat2021TMA', 'hot', 'los', 'https://t.co/rW2qS17IaV', '“', 'strongest', '@BillieEilish', 's', 'self-directed', 'special', 'likely', 'latest', 'past', '2016-2021', 'powerful', 'skilled', 'Zachary', 'powerful', 'skilled', 'Zachary', 'fellow', 'gender-inclusive', '/', 'hear', 'only', 'Nigerian', 'Sade', 'hidden', 'ur', 'same', '#Burnaboy', 'hidden', 'ur', 'same', '#Burnaboy', 'hidden', 'ur', 'same', '#Burnaboy', 'latest', '#music', 'hidden', 'ur', 'same', '#Burnaboy', 'current', '#homestudio', '#recordingartist', '#music']

# %%
from nltk.probability import FreqDist

# Obtener frecuencia de cada término
fdist = FreqDist(data_adjective)
# Convertir a dataframe
df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
df_fdist.sort_values(by=['Frequency'], inplace=True, ascending=False)
#pd.set_option('display.max_rows', None)

df_fdist
# Out:
#                   Frequency
# Term
# latest                    7
# #GRAMMYs                  7
# likely                    6
# first                     5
# #music                    5
# ...                     ...
# Recent                    1
# (310) 882-1967            1
# 🥲                         1
# greatest                  1
# #recordingartist          1
#
# [156 rows x 1 columns]
