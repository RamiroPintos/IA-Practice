# %% [markdown]
# # Obtener datos de la API

# %% [markdown]
# ## Obtener una cuenta de Twitter Developer
#
# - Crear una cuenta en <a href="https://twitter.com/">Twitter</a> o ingresar a una ya creada
# - Solicitar una <a href="https://developer.twitter.com/en/portal/petition/use-case">cuenta de developer</a>
# <br/>
# <img src="img/twitter_api_1.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_2.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_3.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_4.png" style="width:50%;float:left;border:1px solid black">
#
# #### How will you use the Twitter API or Twitter Data?
#
# I will search and filter tweets with specific hashtags in order to perform data mining and sentiment analysis practices. These tasks are part of the Artificial Intelligence course. The extracted data will not be used for any other purpose.
#
# #### Are you planning to analyze Twitter data?
#
# I will perform sentiment analysis of the content of the tweets and their geographical location. The type of content of each tweet will be evaluated (links, images, videos)
#
#
# <br/><br/>
# <img src="img/twitter_api_5.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_6.png" style="width:50%;float:left;border:1px solid black">
#
#
# ### Responder mail
#
# Si Twitter envía un mail solicitando más información responder con el siguiente mensaje.
#
# <code>
#     I will search and filter tweets with specific hashtags in order to perform data mining and sentiment analysis practices. These tasks are part of the Artificial Intelligence course. The extracted data will not be used for any other purpose.
#     I will perform sentiment analysis of the content of the tweets and their geographical location. The type of content of each tweet will be evaluated (links, images, videos)
#     I will not be using the Tweeting, Retweeting, or liking content. I will only use the API to obtain tweets content.
#     The content of the tweets will not be shown. The content will only be used to carry out data analysis exercises during the course.
# </code>

# %% [markdown]
# ## Crear aplicación
#
# - Crear proyecto
# - Crear aplicación dentro del proyecto
# - Obtener y guardar claves (copiar todas las claves antes de continuar ya que no pueden ser accedidas más adelante)
#
# <br/>
# <img src="img/twitter_api_8.png" style="width:30%;float:left;border:1px solid black">
# <img src="img/twitter_api_7.png" style="width:70%;float:left;border:1px solid black">

# %% [markdown]
# ## Cargar Token en variables de entorno
#
#  - Cargar el valor del token en un archivo .env
#  <code>export 'BEARER_TOKEN'='valor del bearer token' </code>
#  - Agregar el archivo .env dentro del .gitignore en caso de trabajar en repositorio

# %% [markdown]
# ## Cargar valor del Token en la aplicación

# %%
import os
from dotenv import load_dotenv
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")

# %% [markdown]
# ## Definir consulta a la API
#
# ### URL de la consulta
#
# Definir la URL de acuerdo a los datos requeridos de acuerdo a la documentación de la <a href="https://developer.twitter.com/en/docs/twitter-api/api-reference-index">API</a>

# %%
url = "https://api.twitter.com/2/tweets/search/recent"

# %% [markdown]
# ## Definir parámetros adicionales
#
# Definr valores como el rango de fecha, hashtag, contenido y campos requeridos.

# %%
params = {
    'query': '#machinelearning -is:retweet',
    'tweet.fields':'created_at',
    'max_results':100
}

# %% [markdown]
# ## Definir cabecera
# La cabecera debe llevar el Token de autenticación para que la consulta sea autorizada

# %%
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"v2FullArchiveSearchPython"
}

# %% [markdown]
# ## Realizar consulta

# %%
import requests
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-20T17:36:15.000Z', 'id': '1450878543186075649', 'text': 'Region features for YOLO architecture #DeepLearning #learning #machinelearning via https://t.co/5KoJKMHpsB https://t.co/66Mde6cYe4'}, {'created_at': '2021-10-20T17:36:00.000Z', 'id': '1450878479692713988', 'text': 'The Train and Test Split in #MachineLearning Process: https://t.co/ioYoMbsjpL #BigData #DataScience #AI'}, {'created_at': '2021-10-20T17:35:52.000Z', 'id': '1450878449032302594', 'text': 'Top 10 Best Laptop In Full Details Review 2021 #BigData #learning #machinelearning via https://t.co/wjnQGYLeUp https://t.co/04titOOR4g'}, {'created_at': '2021-10-20T17:35:12.000Z', 'id': '1450878281067151367', 'text': 'The latest The SAINTS Daily! https://t.co/dyco4ktkP0 #machinelearning #ai'}, {'created_at': '2021-10-20T17:35:04.000Z', 'id': '1450878246447423489', 'text': 'Pass Components as Props in React \n#cybersecurity #devops #100DaysOfCode #ai #codenewbie #machinelearning #DEVCommunity #Python #Serverless #womenintech #flutter \n#WomenWhoCode \n#javascript #DataScience \n#ArtificiallIntelligence \n#programming\n#reactjs \nhttps://t.co/NC1yqNeYNR'}, {'created_at': '2021-10-20T17:34:33.000Z', 'id': '1450878114352017417', 'text': 'The latest The Artificial Intelligence Daily! https://t.co/SgkDVjShMd #ai #machinelearning'}, {'created_at': '2021-10-20T17:34:16.000Z', 'id': '1450878045691187201', 'text': 'The latest PeachTree Capital Advisors! https://t.co/kCtrLzK0S6 #machinelearning #ai'}, {'created_at': '2021-10-20T17:33:40.000Z', 'id': '1450877893412855809', 'text': 'Pass Components as Props in React \n#cybersecurity #devops #100DaysOfCode #ai #codenewbie #machinelearning #DEVCommunity #Python #Serverless #womenintech #flutter \n#WomenWhoCode \n#javascript #DataScience \n#ArtificiallIntelligence \n#programming\n#reactjs \nhttps://t.co/7jeo1OmnCD'}, {'created_at': '2021-10-20T17:33:17.000Z', 'id': '1450877796637683714', 'text': 'Pass Components as Props in React \n#cybersecurity #devops #100DaysOfCode #ai #codenewbie #machinelearning #DEVCommunity #Python #Serverless #womenintech #flutter \n#WomenWhoCode \n#javascript #DataScience \n#ArtificiallIntelligence \n#programming\n#reactjs \nhttps://t.co/zGxy4Fo2bD'}, {'created_at': '2021-10-20T17:33:04.000Z', 'id': '1450877742195490818', 'text': '#python #dummyregressor #sklearn #datascience #machinelearning How to use skearn’s DummyRegressor method https://t.co/PClLVHRfG9'}, {'created_at': '2021-10-20T17:32:56.000Z', 'id': '1450877709144543237', 'text': 'The latest The Future of work Daily! https://t.co/1CTZUEsrJw Thanks to @J3nTyrell #ai #machinelearning'}, {'created_at': '2021-10-20T17:32:51.000Z', 'id': '1450877687883517952', 'text': '#ArtificialIntelligence #AI #MachineLearning #ML https://t.co/mCAnTTFnmr'}, {'created_at': '2021-10-20T17:32:20.000Z', 'id': '1450877556593414147', 'text': 'Pass Components as Props in React \n#cybersecurity #devops #100DaysOfCode #ai #codenewbie #machinelearning #DEVCommunity #Python #Serverless #womenintech #flutter \n#WomenWhoCode \n#javascript #DataScience \n#ArtificiallIntelligence \n#programming\n#reactjs \nhttps://t.co/33msOhCT4b'}, {'created_at': '2021-10-20T17:31:16.000Z', 'id': '1450877288464138252', 'text': 'In this paper, Intel researchers have proposed extend Amdahl’s law to accommodate multiple configurable resources into the overall speedup equation, transforming the speedup equation into a multivariable regression problem suitable for #MachineLearning.\n\nhttps://t.co/YxytcCbwjr https://t.co/x7QzOLkbXK'}, {'created_at': '2021-10-20T17:31:11.000Z', 'id': '1450877267681452034', 'text': 'How anomaly detection could save lives, command #robots, and transform volatile energy markets\n\nhttps://t.co/YpPMhyaetG via @Oracle \n#AI #DigitalTransformation #MachineLearning\n\nCc @jblefevre60 @andi_staub @ahier @sallyeaves @ProustNicolas @schmarzo @Bastwins @Nicochan33 https://t.co/ZnWYnoDccT'}, {'created_at': '2021-10-20T17:30:18.000Z', 'id': '14508770478411 ...

# %% [markdown]
# ## Formatear respuesta
#
# Convertir respuesta en un dataframe de Pandas

# %%
import pandas as pd
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                   created_at                   id  \
# 0   2021-10-20T17:36:15.000Z  1450878543186075649
# 1   2021-10-20T17:36:00.000Z  1450878479692713988
# 2   2021-10-20T17:35:52.000Z  1450878449032302594
# 3   2021-10-20T17:35:12.000Z  1450878281067151367
# 4   2021-10-20T17:35:04.000Z  1450878246447423489
# ..                       ...                  ...
# 95  2021-10-20T17:15:55.000Z  1450873427057852427
# 96  2021-10-20T17:15:37.000Z  1450873352399335432
# 97  2021-10-20T17:15:19.000Z  1450873276994138118
# 98  2021-10-20T17:15:11.000Z  1450873244026875910
# 99  2021-10-20T17:15:11.000Z  1450873241535492096
#
#                                                  text
# 0   Region features for YOLO architecture #DeepLea...
# 1   The Train and Test Split in #MachineLearning P...
# 2   Top 10 Best Laptop In Full Details Review 2021...
# 3   The latest The SAINTS Daily! https://t.co/dyco...
# 4   Pass Components as Props in React \n#cybersecu...
# ..                                                ...
# 95  https://t.co/DDVSG294Jw #BigData #learning #ma...
# 96  Big Data On Amazon Web Services (AWS) Cloud #B...
# 97  The latest Enterprise Mobility News! https://t...
# 98  #hclswlobp #nocode #lowcode #javascript #githu...
# 99  How do opinions on artificial intelligence var...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Ejercicios
#
#  A partir de la documentación del endpoint <a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent"> Recent </a> y las opciones de <a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query"> query </a> obtener:
#
#  - Una lista de las fechas y creación de los tweets realizados por el usuario @kdnuggets que contenga el hashtag #NLP

# %%
params = {
    'query': '#NLP -is:retweet from:kdnuggets',
    'tweet.fields':'created_at',
    'max_results':100
}

# %%
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'meta': {'result_count': 0}}

# %%
df = pd.json_normalize(response.json()['data'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-965c03c79b4e> in <module>
# ----> 1 df = pd.json_normalize(response.json()['data'])
#       2 df
#
# KeyError: 'data'

# %% [markdown]
# - Una lista de los textos y nombres de usuario correspondientes a los tweets que contengan los hashtags #NLP y #MachineLearning que no sean retweets

# %%
params = {
    'query': '#NLP #MachineLearning -is:retweet',
    'tweet.fields':'created_at',
    'expansions': 'author_id',
    'user.fields':'username',
    'max_results':100
}

# %%
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'id': '1450875908982808576', 'text': 'AM Best TV Presents “Advancing Tech Exposes Insurers to Bias Risk” - Business Wire https://t.co/oZDVE9yawn\n\n#DataScience #MachineLearning #DeepLearning #Insurance #NLP #Robots #AI #IoT #BigData', 'created_at': '2021-10-20T17:25:47.000Z', 'author_id': '918112383628963841'}, {'id': '1450875904251637764', 'text': "Insurance Stocks' Q3 Earnings on Oct 21: WRB, MMC, &amp; FAF - Yahoo Finance https://t.co/djfoEvZ3TO\n\n#DataScience #MachineLearning #DeepLearning #Insurance #NLP #Robots #AI #IoT #BigData", 'created_at': '2021-10-20T17:25:46.000Z', 'author_id': '918112383628963841'}, {'id': '1450875512541388809', 'text': 'Hmu for quality assignment help\nEssays\nBiology\nChemistry\nMath\nLaw\nEcology\nAnatomy\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots #Industry40 #javascript \n https://t.co/mOyoOPHhSs', 'created_at': '2021-10-20T17:24:12.000Z', 'author_id': '1341306390862827520'}, {'id': '1450874956607213575', 'text': 'Take a break and listen to this #poem created with Machine Learning.\n#takeabreak #machinelearning #datascience #AI #ArtificialIntelligence  #Technology #Innovation #pythonprogramming #poetry #poemoftheday #AIcreativity #Python #AIart #poems #NLP #botpoetssociety #WritingCommunity https://t.co/hbJ4P6xLjx', 'created_at': '2021-10-20T17:22:00.000Z', 'author_id': '1320676594780934144'}, {'id': '1450874632568033282', 'text': 'HMU for quality assignment help\nEssays\nExams\nBiology\nChemistry\nMath\nLaw\nEcology\nAnatomy\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots #Industry40 #javascript \nhttps://t.co/awalkNPZY3', 'created_at': '2021-10-20T17:20:43.000Z', 'author_id': '1341306390862827520'}, {'id': '1450874449432092676', 'text': '#FrontEndDeveloper \n#DEVCommunity\n#cybersecurity\n#ArtificialIntelligence #AI #DataScience #MachineLearning #BigData #100DaysOfCode #Python #DeepLearning #NLP #Robots #IoT\n#DevOps\n#5G\n#DigitalTransformation\n#CodeNewbie\n#code\n#WomenWhoCode \nhttps://t.co/nk4wf5uB5C', 'created_at': '2021-10-20T17:19:59.000Z', 'author_id': '1409946409499979777'}, {'id': '1450874428666138630', 'text': 'Dm us for help\nExams\nEssays\nBiology\nMath\nEnglish\nChemistry\nAnatomy\nEcology\nHistory\nBiostatistics\nBiochemistry\nPsychology\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots \n#100DaysOfCode', 'created_at': '2021-10-20T17:19:54.000Z', 'author_id': '1341306390862827520'}, {'id': '1450874149853859844', 'text': 'Dm for help\nExams\nEssays\nBiology\nMath\nEnglish\nChemistry\nAnatomy\nEcology\nHistory\nBiostatistics\nBiochemistry\nPsychology\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots \n#100DaysOfCode', 'created_at': '2021-10-20T17:18:47.000Z', 'author_id': '1341306390862827520'}, {'id': '1450873750304477187', 'text': 'Dm us for quality assignment help\nEssays\nExams\nBiology\nChemistry\nMath\nLaw\nEcology\nAnatomy\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots #Industry40 #javascript \nhttps://t.co/awalkNPZY3', 'created_at': '2021-10-20T17:17:12.000Z', 'author_id': '1341306390862827520'}, {'id': '1450873083468918795', 'text': 'Hmu for quality assignment help\nEssays\nExams\nBiology\nChemistry\nMath\nLaw\nEcology\nAnatomy\n#MachineLearning  #DataScience #5G #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP #robots #Industry40 #javascript \nhttps://t.co/awalkNPZY3', 'created_at': '2021-10-20T17:14:33.000Z', 'author_id': '1341306390862827520'}, {'id': '1450872941315563521', 'text': 'Hmu for help\nExams\nEssays\nBiology\nMat ...

# %%
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                      id                                               text  \
# 0   1450875908982808576  AM Best TV Presents “Advancing Tech Exposes In...
# 1   1450875904251637764  Insurance Stocks' Q3 Earnings on Oct 21: WRB, ...
# 2   1450875512541388809  Hmu for quality assignment help\nEssays\nBiolo...
# 3   1450874956607213575  Take a break and listen to this #poem created ...
# 4   1450874632568033282  HMU for quality assignment help\nEssays\nExams...
# ..                  ...                                                ...
# 95  1450798455966691343  College teams closely watching how professiona...
# 96  1450797922673639425  The Myths of AI https://t.co/0OPOcNkWLK via @C...
# 97  1450797645124014082  Implications of #ArtificialIntelligence (#AI) ...
# 98  1450794189269176330  The Myths of AI https://t.co/kSTi71MMJq #Docup...
# 99  1450793352648089602  Explore the differences between NLP and machin...
#
#                   created_at            author_id
# 0   2021-10-20T17:25:47.000Z   918112383628963841
# 1   2021-10-20T17:25:46.000Z   918112383628963841
# 2   2021-10-20T17:24:12.000Z  1341306390862827520
# 3   2021-10-20T17:22:00.000Z  1320676594780934144
# 4   2021-10-20T17:20:43.000Z  1341306390862827520
# ..                       ...                  ...
# 95  2021-10-20T12:18:01.000Z            444522096
# 96  2021-10-20T12:15:53.000Z           1704823387
# 97  2021-10-20T12:14:47.000Z             18229080
# 98  2021-10-20T12:01:03.000Z   950410848283119616
# 99  2021-10-20T11:57:44.000Z   971285747662770176
#
# [100 rows x 4 columns]

# %%
df_users = pd.json_normalize(response.json()['includes']['users'])
df_users.rename(columns={'id': 'author_id'}, inplace=True)
df_users
# Out:
#               author_id                                           name  \
# 0    918112383628963841                                     David Sobo
# 1   1341306390862827520                              Excellent Writers
# 2   1320676594780934144                              Bot Poets Society
# 3   1409946409499979777                                 Sally M. Fedor
# 4   1083699084760895496                                        Nikseam
# 5    950410848283119616                                        C-Suite
# 6   1446513127055511552                                       Thomas M
# 7    843593628337553408                                      KUNGFU.AI
# 8             300750392                                       Verinite
# 9   1403014419953635332                BEST ASSIGNMENTS AND ESSAY HELP
# 10            467513287                                Iain Brown, PhD
# 11            268619848                               Syeda Sheraj Ali
# 12  1025638818068590592   Dr. Monika Sonu, CEO Healthinnovationtoolbox
# 13             32837749           Dr. Angshuman Ghosh (Ph.D., MBA, BE)
# 14  1122371194370625536      Assignment Help, Essay due, Homework help
# 15  1179102789047324672                             Assignment Experts
# 16             82293310                                   SoftwareMill
# 17  1368227387985526787                                       WMK Tech
# 18  1446189216652795906                                    wajdi kayal
# 19  1445434368957325330                                    wajdi kayal
# 20  1450314482329079809                                 Angela Daniels
# 21  1446146388446912525                                    Wajdi Kayal
# 22  1364806129717563394                            W a j d i k a y a l
# 23  1438455622001782785                                      Ruth burk
# 24  1399707627597279236                                    Businessbea
# 25           2591072096                                   allegro.tech
# 26            156568938                                Andres Vilariño
# 27  1067368422491729920                                        CogNeed
# 28           3068690196                                Brian E. Thomas
# 29            171464986                    Regenstrief Institute, Inc.
# 30           1264433760                                 Elitsa Krumova
# 31           2433952247     Best academics Tutors/Homework/Assignments
# 32  1321862814051536896  Academic Homework/Assignment/Exams and Essays
# 33  1400418183052283911                                      Indika AI
# 34           1954706040                                  Nicolas Pinto
# 35   752910638192660482                                       Virtuoso
# 36  1019916306160799745                                       Automeme
# 37   787744952503504896                          Coruzant Technologies
# 38           1643123766                                          Umair
# 39   705539763349164032                                     ipfconline
# 40             18622427                                Reluctant Quant
# 41  1442886288927981570                                     Tony Edwin
# 42  1435645100051206154                                    Neil Esparz
# 43   810185161576890368                                Er.Satyam Bhatt
# 44  1422214344754925570                                    Brock Dyess
# 45            444522096                                  Colin Bristow
# 46           1704823387                                    Chris Meyer
# 47             18229080                                 Chris Rigatuso
# 48   971285747662770176                                   PredictSense
#
#            username
# 0      DS_Analytics
# 1   writersxcellent
# 2   BotPoetsSociety
# 3        FedorSally
# 4          NikseamC
# 5         CSuitePro
# 6    Thomas91580600
# 7          kungfuai
# 8          Verinite
# 9    MAYASSIGNMENT1
# 10      IainLJBrown
# 11         Sheraj99
# 12      sonu_monika
# 13         drangshu
# 14  eliteessays2013
# 15    assignmentvip
# 16     softwaremill
# 17          wmktech
# 18      wajdikayal2
# 19      wajdi_kayal
# 20  Angela79D841848
# 21      WajdiKayal1
# 22    Wajdialkayal1
# 23  JordaneLuettge1
# 24      businessbea
# 25      allegrotech
# 26   andresvilarino
# 27          CogNeed
# 28     DivergentCIO
# 29      Regenstrief
# 30      Eli_Krumova
# 31  OnlineLegitHelp
# 32        Rezzy2541
# 33        Indika_AI
# 34    Nicolas2Pinto
# 35      Virtuoso_QA
# 36         automeme
# 37         Coruzant
# 38    akbarth3great
# 39      ipfconline1
# 40    DrMattCrowson
# 41  TonyEdw68907630
# 42       EsparzNeil
# 43     SatyamBhatta
# 44       BrockDyess
# 45     BristowColin
# 46         OnTopBln
# 47        crigatuso
# 48     PredictSense

# %%
pd.merge(df, df_users, on="author_id")
# Out:
#                      id                                               text  \
# 0   1450875908982808576  AM Best TV Presents “Advancing Tech Exposes In...
# 1   1450875904251637764  Insurance Stocks' Q3 Earnings on Oct 21: WRB, ...
# 2   1450860725199593472  Origami Risk Enhances Workers' Comp Claims Adm...
# 3   1450845581849550852  AM Best Upgrades Issuer Credit Rating for Farm...
# 4   1450830483298865152  New Analysis from Global Industry Analysts Rev...
# ..                  ...                                                ...
# 95  1450801466424193025  How To Remove Bad Reviews From Google Local\nh...
# 96  1450798455966691343  College teams closely watching how professiona...
# 97  1450797922673639425  The Myths of AI https://t.co/0OPOcNkWLK via @C...
# 98  1450797645124014082  Implications of #ArtificialIntelligence (#AI) ...
# 99  1450793352648089602  Explore the differences between NLP and machin...
#
#                   created_at            author_id            name  \
# 0   2021-10-20T17:25:47.000Z   918112383628963841      David Sobo
# 1   2021-10-20T17:25:46.000Z   918112383628963841      David Sobo
# 2   2021-10-20T16:25:27.000Z   918112383628963841      David Sobo
# 3   2021-10-20T15:25:16.000Z   918112383628963841      David Sobo
# 4   2021-10-20T14:25:17.000Z   918112383628963841      David Sobo
# ..                       ...                  ...             ...
# 95  2021-10-20T12:29:58.000Z  1422214344754925570     Brock Dyess
# 96  2021-10-20T12:18:01.000Z            444522096   Colin Bristow
# 97  2021-10-20T12:15:53.000Z           1704823387     Chris Meyer
# 98  2021-10-20T12:14:47.000Z             18229080  Chris Rigatuso
# 99  2021-10-20T11:57:44.000Z   971285747662770176    PredictSense
#
#         username
# 0   DS_Analytics
# 1   DS_Analytics
# 2   DS_Analytics
# 3   DS_Analytics
# 4   DS_Analytics
# ..           ...
# 95    BrockDyess
# 96  BristowColin
# 97      OnTopBln
# 98     crigatuso
# 99  PredictSense
#
# [100 rows x 6 columns]

# %% [markdown]
# - Una lista de los textos y enlaces de los tweets que contengan los hashtags #InteligenciaArtificial o #IA en español

# %%
params = {
    'query': '(#InteligenciaArtificial OR #IA) lang:es -is:retweet',
    'tweet.fields':'created_at,entities',
    'expansions': 'author_id',
    'user.fields':'username',
    'max_results':100
}

# %%
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-20T17:34:58.000Z', 'entities': {'mentions': [{'start': 115, 'end': 129, 'username': 'CNT_infoLibre', 'id': '1320674590335684608'}], 'urls': [{'start': 81, 'end': 104, 'url': 'https://t.co/pDIcINW61E', 'expanded_url': 'https://paper.li/Interconexiona/1463484771?pub_id=b8594899-fd71-40ff-bd32-8430cdd7995e', 'display_url': 'paper.li/Interconexiona…'}], 'hashtags': [{'start': 13, 'end': 28, 'tag': 'Interconexiona'}, {'start': 32, 'end': 39, 'tag': 'Empleo'}, {'start': 40, 'end': 45, 'tag': 'RRHH'}, {'start': 46, 'end': 60, 'tag': 'MarcaPersonal'}, {'start': 61, 'end': 80, 'tag': 'Orientacionlaboral'}, {'start': 130, 'end': 153, 'tag': 'inteligenciaartificial'}, {'start': 154, 'end': 163, 'tag': 'startups'}]}, 'id': '1450878220673429507', 'text': 'Lo último de #Interconexiona en #Empleo #RRHH #MarcaPersonal #Orientacionlaboral https://t.co/pDIcINW61E gracias a @CNT_infoLibre #inteligenciaartificial #startups', 'author_id': '617338053'}, {'created_at': '2021-10-20T17:34:19.000Z', 'id': '1450878057661833220', 'entities': {'urls': [{'start': 235, 'end': 258, 'url': 'https://t.co/yHupE7wDFJ', 'expanded_url': 'https://twitter.com/BrazilSFE/status/1450878057661833220/photo/1', 'display_url': 'pic.twitter.com/yHupE7wDFJ'}], 'hashtags': [{'start': 68, 'end': 72, 'tag': 'EMA'}, {'start': 73, 'end': 77, 'tag': 'GSK'}, {'start': 78, 'end': 103, 'tag': 'IndústriadeBiotecnologia'}, {'start': 104, 'end': 127, 'tag': 'InteligênciaArtificial'}, {'start': 128, 'end': 143, 'tag': 'Leukodystrophy'}, {'start': 144, 'end': 153, 'tag': 'Libmeldy'}, {'start': 154, 'end': 174, 'tag': 'OrchardTherapeutics'}, {'start': 175, 'end': 190, 'tag': 'OryzonGenomics'}, {'start': 191, 'end': 200, 'tag': 'Prolupin'}, {'start': 201, 'end': 216, 'tag': 'SophiaGenetics'}, {'start': 217, 'end': 234, 'tag': 'ValoTherapeutics'}]}, 'text': '5 DAS 21 Empresas de Biotecnologia Europeias\n✔ Brazil SFE Company®\n\n#EMA #GSK #IndústriadeBiotecnologia #InteligênciaArtificial #Leukodystrophy #Libmeldy #OrchardTherapeutics #OryzonGenomics #Prolupin #SophiaGenetics #ValoTherapeutics https://t.co/yHupE7wDFJ', 'author_id': '2956693744'}, {'created_at': '2021-10-20T17:30:35.000Z', 'entities': {'annotations': [{'start': 125, 'end': 150, 'probability': 0.2614, 'type': 'Person', 'normalized_text': 'Santiago Battán Horenstein'}], 'mentions': [{'start': 73, 'end': 89, 'username': 'ArgentinaCamara', 'id': '1308068540822544387'}, {'start': 91, 'end': 107, 'username': 'IdentidadArgen2', 'id': '1225434640636354560'}], 'urls': [{'start': 218, 'end': 241, 'url': 'https://t.co/DHMiXPtMjh', 'expanded_url': 'https://lnkd.in/dbCieJnG', 'display_url': 'lnkd.in/dbCieJnG', 'images': [{'url': 'https://pbs.twimg.com/news_img/1450538059250941957/iKcj1zu8?format=jpg&name=orig', 'width': 1200, 'height': 630}, {'url': 'https://pbs.twimg.com/news_img/1450538059250941957/iKcj1zu8?format=jpg&name=150x150', 'width': 150, 'height': 150}], 'status': 200, 'title': 'Transformación digital basada en datos', 'unwound_url': 'https://docs.google.com/forms/d/e/1FAIpQLSdKykJGrlJ4YPbJp0yyP2ZYgGJQH_nINgg1igcIKP_BT6AA4w/viewform?usp=send_form'}, {'start': 280, 'end': 303, 'url': 'https://t.co/97D62MFsDX', 'expanded_url': 'https://twitter.com/GuilleSSuarez/status/1450877117445648393/photo/1', 'display_url': 'pic.twitter.com/97D62MFsDX'}], 'hashtags': [{'start': 38, 'end': 49, 'tag': 'innovación'}, {'start': 53, 'end': 66, 'tag': 'Conocimiento'}, {'start': 165, 'end': 187, 'tag': 'transformacióndigital'}, {'start': 198, 'end': 204, 'tag': 'datos'}, {'start': 242, 'end': 265, 'tag': 'InteligenciaArtificial'}, {'start': 267, 'end': 279, 'tag': 'DataScience'}]}, 'id': '1450877117445648393', 'text': 'Este Jueves!! nueva edición del Ciclo #innovación  y #Conocimiento de la @ArgentinaCamara  @IdentidadArgen2!\n´25 del experto Santiago Battán Horenstein acerca de la #transformacióndigital basada en #datos \nInscríbete: https://t.co/DHMiXPtMjh\n#InteligenciaArtificial  #DataScience https://t.co/97D62MF ...

# %%
df = pd.json_normalize(response.json()['data'])
df.drop(columns=['entities.annotations','entities.hashtags','entities.mentions'],inplace=True)
#df["url_aux"] = [df['entities.urls'][i][0]['url'] for i in range(len(df['entities.urls']))]
#print(df['entities.urls'])
df
# Out:
#                   created_at                   id  \
# 0   2021-10-20T17:34:58.000Z  1450878220673429507
# 1   2021-10-20T17:34:19.000Z  1450878057661833220
# 2   2021-10-20T17:30:35.000Z  1450877117445648393
# 3   2021-10-20T17:30:32.000Z  1450877106087469058
# 4   2021-10-20T17:29:30.000Z  1450876842949451787
# ..                       ...                  ...
# 95  2021-10-20T13:40:48.000Z  1450819290765135876
# 96  2021-10-20T13:39:28.000Z  1450818953169752067
# 97  2021-10-20T13:36:57.000Z  1450818323051171845
# 98  2021-10-20T13:36:08.000Z  1450818117773447168
# 99  2021-10-20T13:29:43.000Z  1450816501783699463
#
#                                                  text            author_id  \
# 0   Lo último de #Interconexiona en #Empleo #RRHH ...            617338053
# 1   5 DAS 21 Empresas de Biotecnologia Europeias\n...           2956693744
# 2   Este Jueves!! nueva edición del Ciclo #innovac...           2499492799
# 3   @iLABMex invita al panel internacional: Labora...            104654597
# 4   El futuro en la securización de espacios en ce...           1200581984
# ..                                                ...                  ...
# 95  🆕📰 @Bolsamania: KPMG distribuirá la nueva plat...            613074939
# 96  🆕📰 @europapress: KPMG distribuirá la nueva pla...            613074939
# 97  #Algoritmos en RRSS son más #Peligrosos que oj...           3287967557
# 98  La #inteligenciaartificial nos impacta en nues...  1442754255581073409
# 99  Las compañías requieren los servicios de Verti...            165109399
#
#                                     entities.mentions  \
# 0   [{'start': 115, 'end': 129, 'username': 'CNT_i...
# 1                                                 NaN
# 2   [{'start': 73, 'end': 89, 'username': 'Argenti...
# 3   [{'start': 0, 'end': 8, 'username': 'iLABMex',...
# 4   [{'start': 265, 'end': 279, 'username': 'Geria...
# ..                                                ...
# 95  [{'start': 3, 'end': 14, 'username': 'bolsaman...
# 96  [{'start': 3, 'end': 15, 'username': 'europapr...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                         entities.urls  \
# 0   [{'start': 81, 'end': 104, 'url': 'https://t.c...
# 1   [{'start': 235, 'end': 258, 'url': 'https://t....
# 2   [{'start': 218, 'end': 241, 'url': 'https://t....
# 3   [{'start': 127, 'end': 150, 'url': 'https://t....
# 4   [{'start': 236, 'end': 259, 'url': 'https://t....
# ..                                                ...
# 95  [{'start': 90, 'end': 113, 'url': 'https://t.c...
# 96  [{'start': 91, 'end': 114, 'url': 'https://t.c...
# 97  [{'start': 205, 'end': 228, 'url': 'https://t....
# 98                                                NaN
# 99  [{'start': 232, 'end': 255, 'url': 'https://t....
#
#                                     entities.hashtags  \
# 0   [{'start': 13, 'end': 28, 'tag': 'Interconexio...
# 1   [{'start': 68, 'end': 72, 'tag': 'EMA'}, {'sta...
# 2   [{'start': 38, 'end': 49, 'tag': 'innovación'}...
# 3   [{'start': 151, 'end': 169, 'tag': 'innovacion...
# 4   [{'start': 91, 'end': 114, 'tag': 'Inteligenci...
# ..                                                ...
# 95  [{'start': 115, 'end': 118, 'tag': 'IA'}, {'st...
# 96  [{'start': 116, 'end': 119, 'tag': 'IA'}, {'st...
# 97  [{'start': 0, 'end': 11, 'tag': 'Algoritmos'},...
# 98  [{'start': 3, 'end': 26, 'tag': 'inteligenciaa...
# 99  [{'start': 256, 'end': 267, 'tag': 'DataCenter...
#
#                                  entities.annotations
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'start': 125, 'end': 150, 'probability': 0.2...
# 3   [{'start': 78, 'end': 91, 'probability': 0.465...
# 4   [{'start': 174, 'end': 182, 'probability': 0.7...
# ..                                                ...
# 95  [{'start': 18, 'end': 21, 'probability': 0.628...
# 96  [{'start': 19, 'end': 22, 'probability': 0.628...
# 97  [{'start': 63, 'end': 68, 'probability': 0.491...
# 98                                                NaN
# 99  [{'start': 41, 'end': 46, 'probability': 0.517...
#
# [100 rows x 8 columns]

# %%
# Obtenemos indices de muestras con alive-at-1 faltante
index_to_drop = df[pd.isna(df['entities.urls'])].index
# Eliminar esos índices de el dataframe
df = df.drop(index_to_drop, axis=0)
df
# Out:
#               author_id                   id                created_at  \
# 0   1361813588093018112  1443597309921562628  2021-09-30T15:23:14.000Z
# 2   1123930563751051271  1443597049568583684  2021-09-30T15:22:12.000Z
# 3             130792364  1443596832182095881  2021-09-30T15:21:20.000Z
# 5             170027490  1443596526664753164  2021-09-30T15:20:07.000Z
# 6    958956108890034176  1443596496792952838  2021-09-30T15:20:00.000Z
# ..                  ...                  ...                       ...
# 95            613074939  1443555476642299906  2021-09-30T12:37:00.000Z
# 96  1046893958918541312  1443554349335076868  2021-09-30T12:32:31.000Z
# 97             93828125  1443554010561060868  2021-09-30T12:31:10.000Z
# 98            111706303  1443553726724288515  2021-09-30T12:30:03.000Z
# 99             42742469  1443553004691410950  2021-09-30T12:27:10.000Z
#
#                                                  text  \
# 0   ¿Cuándo es necesario desarrollar tecnologías d...
# 2   GPT-3 ¿Un paso más cerca de la Inteligencia Ar...
# 3   La #InteligenciaArtificial se alimenta de dato...
# 5   🤖Demos a conocer los proyectos que construyen ...
# 6   La #TransformaciónDigital hace especial uso de...
# ..                                                ...
# 95  🤔 ¿Alguna vez te has preguntado qué es la #IA?...
# 96  ¿Sabíais que es posible usar nuestra #onesaitP...
# 97  Un informe de @Gartner_inc apunta que un terci...
# 98  Las empresas que consideran estratégica su #Co...
# 99  Caja Real de @lauaslp \n#SLP\n#enSanLuis \n.\n...
#
#                                         entities.urls
# 0   [{'start': 66, 'end': 89, 'url': 'https://t.co...
# 2   [{'start': 247, 'end': 270, 'url': 'https://t....
# 3   [{'start': 237, 'end': 260, 'url': 'https://t....
# 5   [{'start': 236, 'end': 259, 'url': 'https://t....
# 6   [{'start': 278, 'end': 301, 'url': 'https://t....
# ..                                                ...
# 95  [{'start': 79, 'end': 102, 'url': 'https://t.c...
# 96  [{'start': 213, 'end': 236, 'url': 'https://t....
# 97  [{'start': 158, 'end': 181, 'url': 'https://t....
# 98  [{'start': 178, 'end': 201, 'url': 'https://t....
# 99  [{'start': 109, 'end': 132, 'url': 'https://t....
#
# [89 rows x 5 columns]

# %%
values = []
for v in df['entities.urls'][:]:
    values.append(v[0]['url'])
df['entities.urls'] = values
df
# Out:
#               author_id                   id                created_at  \
# 0   1361813588093018112  1443597309921562628  2021-09-30T15:23:14.000Z
# 2   1123930563751051271  1443597049568583684  2021-09-30T15:22:12.000Z
# 3             130792364  1443596832182095881  2021-09-30T15:21:20.000Z
# 5             170027490  1443596526664753164  2021-09-30T15:20:07.000Z
# 6    958956108890034176  1443596496792952838  2021-09-30T15:20:00.000Z
# ..                  ...                  ...                       ...
# 95            613074939  1443555476642299906  2021-09-30T12:37:00.000Z
# 96  1046893958918541312  1443554349335076868  2021-09-30T12:32:31.000Z
# 97             93828125  1443554010561060868  2021-09-30T12:31:10.000Z
# 98            111706303  1443553726724288515  2021-09-30T12:30:03.000Z
# 99             42742469  1443553004691410950  2021-09-30T12:27:10.000Z
#
#                                                  text            entities.urls
# 0   ¿Cuándo es necesario desarrollar tecnologías d...  https://t.co/wzDSLyg1mP
# 2   GPT-3 ¿Un paso más cerca de la Inteligencia Ar...  https://t.co/sYENh8pRbn
# 3   La #InteligenciaArtificial se alimenta de dato...  https://t.co/t26M9JcDgk
# 5   🤖Demos a conocer los proyectos que construyen ...  https://t.co/h6YpO6P2gV
# 6   La #TransformaciónDigital hace especial uso de...  https://t.co/gKE7gPorjS
# ..                                                ...                      ...
# 95  🤔 ¿Alguna vez te has preguntado qué es la #IA?...  https://t.co/HPrH8Pxeab
# 96  ¿Sabíais que es posible usar nuestra #onesaitP...  https://t.co/WrlhYX1SFi
# 97  Un informe de @Gartner_inc apunta que un terci...  https://t.co/IQDINASLRr
# 98  Las empresas que consideran estratégica su #Co...  https://t.co/syjp1tMQqP
# 99  Caja Real de @lauaslp \n#SLP\n#enSanLuis \n.\n...  https://t.co/IrURBzSjyl
#
# [89 rows x 5 columns]

# %% [markdown]
# ## Descargar a CSV

# %%
params = {
    'query': '(#InteligenciaArtificial OR #IA) lang:es -is:retweet',
    'tweet.fields':'created_at,entities',
    'expansions': 'author_id',
    'user.fields':'username',
    'max_results':100
}
url = "https://api.twitter.com/2/tweets/search/recent"

# %%
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(dict(response.json())['meta'])
def get_data(url,params):
    results = []

    while True:
        response = requests.get(url, headers=headers, params=params)
        # Generar excepción si la respuesta no es exitosa
        if response.status_code != 200:
            raise Exception(response.status_code, response.text)
        data = response.json()['data']
        meta_data = dict(response.json())['meta']
        results.append(pd.json_normalize(data))
        if 'next_token' not in meta_data:
            break
        else:
            token = meta_data['next_token']
            print(token)
            params = {
                'query': '(#InteligenciaArtificial OR #IA) lang:es -is:retweet',
                'tweet.fields':'created_at,entities',
                'expansions': 'author_id',
                'user.fields':'username',
                'next_token':token,
                'max_results':100
            }
    return pd.concat(results)
df = get_data(url,params)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b153c0e4062a> in <module>
# ----> 1 response = requests.get(url, headers=headers, params=params)
#       2 print(response)
#       3 # Generar excepción si la respuesta no es exitosa
#       4 if response.status_code != 200:
#       5     raise Exception(response.status_code, response.text)
#
# NameError: name 'requests' is not defined

# %%
df.to_csv('tweets_ej')
